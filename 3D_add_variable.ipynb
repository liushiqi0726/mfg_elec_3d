# %%
import numpy as np
from scipy.stats import norm
import matplotlib
import matplotlib.pyplot as plt
import time
from scipy.optimize import root_scalar, minimize
from scipy.stats import gamma
from scipy.stats import beta
from scipy.linalg import block_diag
import random
import pandas as pd
from functools import reduce

import gurobipy as gp
from gurobipy import GRB

# Constants
# peak hours
pcoef = 65./168
# off-peak hours
opcoef = 103./168
# conversion of hourly revenue per MW into annual revenue per kW
convcoef = 24.*365.25/1000.
# baseline supply
def F0(X):
    return 17.5*X/150.
# Integrated baseline supply function
def G0(X):
    return 17.5*X*X/300.
# price cap
Pmax = 200


class Agent: # Base class for any producer

    def __init__(self,name,cp,ap):
        # name : name of agent
        # cp : common parameters
        # ap : agent parameters
        # described in derived classes
        self.name = name
        self.Nt = cp['Nt']
        self.NX = ap['NX']
        self.Na=2
        
        
        self.Amin=0
        self.Amax=25
        
        self.Abar=cp['tmax']
        self.da=1.*(self.Abar)/(self.Na-1)
        self.dX = 1.*(ap['Xmax']-ap['Xmin'])/(self.NX-1)
        self.dt = 1.*(cp['tmax']-cp['tmin'])/(self.Nt-1)
        self.X = np.linspace(ap['Xmin'],ap['Xmax'],self.NX)
        self.T = np.linspace(cp['tmin'],cp['tmax'],self.Nt)
        self.A= np.linspace(self.Amin,self.Amax,self.Na)
        self.rho = ap['discount rate']
        self.gamma0 = ap['depreciation rate']
        self.rCost = ap['running cost']
        self.fCost = ap['fixed cost']
        self.sCost = ap['scrap value']
        self.tmax = cp['tmax']
        self.m_ = np.zeros((self.Nt,self.Na,self.NX))
        self.mhat_ = np.zeros((self.Nt,self.Na,self.NX))
        self.mu_ = np.zeros((self.Nt,self.Na,self.NX))
        self.muhat_ = np.zeros((self.Nt,self.Na,self.NX))
        self.mtau_ = np.zeros((self.Nt,self.NX))
        self.mutau_ = np.zeros((self.Nt,self.NX))



    def preCalc(self,indens,indenshat,V,V0,V1,V2):
        # Some technical preliminary computations
        self.m_[0,:,:] = indens[:,:]
        self.mhat_[0,:,:] = indenshat[:,:]
        with gp.Env(empty=True) as env:
            env.setParam('OutputFlag', 0)
            env.start()
            self.model = gp.Model(env=env)
        self.mhat= [[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Na)] for _ in range(self.Nt-1)]
        self.m = [[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Na)] for _ in range(self.Nt-1)]
        self.muhat = [[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Na)] for _ in range(self.Nt-1)]
        self.mu = [[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Na)] for _ in range(self.Nt-1)]
        self.mtau=[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.mutau=[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        #case i!=0
        for i in range(1,self.Nt-1):
            #z!=0, j!=Nx-1, j!=0
            for z in range(1,self.Na):
                for j in range(1,self.NX-1):
                    expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],-self.dt/self.da, self.dt,-self.dt,-1.],[self.m[i][z][j],self.m[i][z][j+1],self.m[i][z][j-1],self.m[i][z-1][j],self.mu[i][z][j],self.muhat[i][z][j],self.m[i-1][z][j]])
                    self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                    #print(expr)
                    expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],-self.dt/self.da, self.dt,-1.],[self.mhat[i][z][j],self.mhat[i][z][j+1],self.mhat[i][z][j-1],self.mhat[i][z-1][j],self.muhat[i][z][j],self.mhat[i-1][z][j]])
                    self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                    
                    expr=gp.LinExpr([V0[j],V1[j+1],V2[j-1], self.dt,-self.dt,-1.],[self.mtau[i][j],self.mtau[i][j+1],self.mtau[i][j-1],self.mutau[i][j],self.m[i][self.Na-1][j],self.mtau[i-1][j]])
                    self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                    
                    
            #z!=0, j=0 or j=NX-1
                expr = gp.LinExpr([V[0],V1[1],-self.dt/self.da,self.dt,-self.dt,-1.],[self.m[i][z][0],self.m[i][z][1],self.m[i][z-1][0],self.mu[i][z][0],self.muhat[i][z][0],self.m[i-1][z][0]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],-self.dt/self.da,self.dt,-self.dt,-1.],[self.m[i][z][self.NX-1],self.m[i][z][self.NX-2],self.m[i][z-1][self.NX-1],self.mu[i][z][self.NX-1],self.muhat[i][z][self.NX-1],self.m[i-1][z][self.NX-1]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                expr = gp.LinExpr([V[0],V1[1],-self.dt/self.da,self.dt,-1.],[self.mhat[i][z][0],self.mhat[i][z][1],self.mhat[i][z-1][0],self.muhat[i][z][0],self.mhat[i-1][z][0]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],-self.dt/self.da,self.dt,-1.],[self.mhat[i][z][self.NX-1],self.mhat[i][z][self.NX-2],self.mhat[i][z-1][self.NX-1],self.muhat[i][z][self.NX-1],self.mhat[i-1][z][self.NX-1]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                
                
                expr=gp.LinExpr([V0[0],V1[1],self.dt,-self.dt,-1.],[self.mtau[i][0],self.mtau[i][1],self.mutau[i][0],self.m[i][self.Na-1][0],self.mtau[i-1][0]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            
                
                expr=gp.LinExpr([V0[self.NX-1],V2[self.NX-2], self.dt,-self.dt,-1.],[self.mtau[i][self.NX-1],self.mtau[i][self.NX-2],self.mutau[i][self.NX-1],self.m[i][self.Na-1][self.NX-1],self.mtau[i-1][self.NX-1]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                
            # z=0, j!=NX-1, j!=0, remove m[i][z-1][j]
            for j in range(1,self.NX-1):
                expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],self.dt,-self.dt,-1.],[self.m[i][0][j],self.m[i][0][j+1],self.m[i][0][j-1],self.mu[i][0][j],self.muhat[i][0][j],self.m[i-1][0][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0)
                expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],self.dt,-1.],[self.mhat[i][0][j],self.mhat[i][0][j+1],self.mhat[i][0][j-1],self.muhat[i][0][j],self.mhat[i-1][0][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0)
                
                expr=gp.LinExpr([V0[j],V1[j+1],V2[j-1],self.dt,-self.dt,-1.],[self.mtau[i][j],self.mtau[i][j+1],self.mtau[i][j-1],self.mutau[i][j],self.m[i][self.Na-1][j],self.mtau[i-1][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                
                
                
                
            #z=0, j=Nx or j=0
            expr = gp.LinExpr([V[0],V1[1],self.dt,-self.dt,-1],[self.m[i][0][0],self.m[i][0][1],self.mu[i][0][0],self.muhat[i][0][0],self.m[i-1][0][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0)
            expr = gp.LinExpr([V[0],V1[1],self.dt,-1],[self.mhat[i][0][0],self.mhat[i][0][1],self.muhat[i][0][0],self.mhat[i-1][0][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0)
            expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],self.dt,-self.dt,-1],[self.m[i][0][self.NX-1],self.m[i][0][self.NX-2],self.mu[i][0][self.NX-1],self.muhat[i][0][self.NX-1],self.m[i-1][0][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0)
            expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],self.dt,-1],[self.mhat[i][0][self.NX-1],self.mhat[i][0][self.NX-2],self.muhat[i][0][self.NX-1],self.mhat[i-1][0][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0)
            
            
            expr=gp.LinExpr([V0[0],V1[1],self.dt,-self.dt,-1.],[self.mtau[i][0],self.mtau[i][1],self.mutau[i][0],self.m[i][self.Na-1][0],self.mtau[i-1][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            
                
            expr=gp.LinExpr([V0[self.NX-1],V2[self.NX-2], self.dt,-self.dt,-1.],[self.mtau[i][self.NX-1],self.mtau[i][self.NX-2],self.mutau[i][self.NX-1],self.m[i][self.Na-1][self.NX-1],self.mtau[i-1][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
        
        
        #case i=0
        #z!=0, j!=0, j!=NX-1
        for z in range(1,self.Na):
            for j in range(1,self.NX-1):
                expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],-self.dt/self.da,self.dt,-self.dt],[self.m[0][z][j],self.m[0][z][j+1],self.m[0][z][j-1],self.m[0][z-1][j],self.mu[0][z][j],self.muhat[0][z][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[z,j])

                expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],-self.dt/self.da,self.dt],[self.mhat[0][z][j],self.mhat[0][z][j+1],self.mhat[0][z][j-1],self.mhat[0][z-1][j],self.muhat[0][z][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[z,j])
                
                expr=gp.LinExpr([V0[j],V1[j+1],V2[j-1], self.dt,-self.dt],[self.mtau[0][j],self.mtau[0][j+1],self.mtau[0][j-1],self.mutau[0][j],self.m[0][self.Na-1][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                
            # i=0,z!=0 j=0 or j=NX-1
            expr = gp.LinExpr([V[0],V1[1],-self.dt/self.da,self.dt,-self.dt],[self.m[0][z][0],self.m[0][z][1],self.m[0][z-1][0],self.mu[0][z][0],self.muhat[0][z][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[z,0])

            expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],-self.dt/self.da,self.dt,-self.dt],[self.m[0][z][self.NX-1],self.m[0][z][self.NX-2],self.m[0][z-1][self.NX-1],self.mu[0][z][self.NX-1],self.muhat[0][z][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[z,self.NX-1])

            expr = gp.LinExpr([V[0],V1[1],-self.dt/self.da,self.dt],[self.mhat[0][z][0],self.mhat[0][z][1],self.mhat[0][z-1][0],self.muhat[0][z][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[z,0])

            expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],-self.dt/self.da,self.dt],[self.mhat[0][z][self.NX-1],self.mhat[0][z][self.NX-2],self.mhat[0][z-1][self.NX-1],self.muhat[0][z][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[z,self.NX-1])
         
            expr=gp.LinExpr([V0[0],V1[1],self.dt,-self.dt],[self.mtau[0][0],self.mtau[0][1],self.mutau[0][0],self.m[0][self.Na-1][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            
                
            expr=gp.LinExpr([V0[self.NX-1],V2[self.NX-2], self.dt,-self.dt],[self.mtau[0][self.NX-1],self.mtau[0][self.NX-2],self.mutau[0][self.NX-1],self.m[0][self.Na-1][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
        
        
        
        #i=0,z=0, j!=0 or j!=NX-1
            
            
        for j in range(1,self.NX-1):
            expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],self.dt,-self.dt],[self.m[0][0][j],self.m[0][0][j+1],self.m[0][0][j-1],self.mu[0][0][j],self.muhat[0][0][j]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[0,j])

            expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],self.dt],[self.mhat[0][0][j],self.mhat[0][0][j+1],self.mhat[0][0][j-1],self.muhat[0][0][j]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[0,j])

            
            expr=gp.LinExpr([V0[j],V1[j+1],V2[j-1], self.dt,-self.dt],[self.mtau[0][j],self.mtau[0][j+1],self.mtau[0][j-1],self.mutau[0][j],self.m[0][self.Na-1][j]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0)
            #i=0, z=0, j=0 or j=NX-1
        expr = gp.LinExpr([V[0],V1[1],self.dt,-self.dt],[self.m[0][0][0],self.m[0][0][1],self.mu[0][0][0],self.muhat[0][0][0]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[0,0])

        expr = gp.LinExpr([V[0],V1[1],self.dt],[self.mhat[0][0][0],self.mhat[0][0][1],self.muhat[0][0][0]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[0,0])

        expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],self.dt,-self.dt],[self.m[0][0][self.NX-1],self.m[0][0][self.NX-2],self.mu[0][0][self.NX-1],self.muhat[0][0][self.NX-1]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[0,self.NX-1])

        expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],self.dt],[self.mhat[0][0][self.NX-1],self.mhat[0][0][self.NX-2],self.muhat[0][0][self.NX-1]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[0,self.NX-1]) 

        
        expr=gp.LinExpr([V0[0],V1[1],self.dt,-self.dt],[self.mtau[0][0],self.mtau[0][1],self.mutau[0][0],self.m[0][self.Na-1][0]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0)
            
                
        expr=gp.LinExpr([V0[self.NX-1],V2[self.NX-2], self.dt,-self.dt],[self.mtau[0][self.NX-1],self.mtau[0][self.NX-2],self.mutau[0][self.NX-1],self.m[0][self.Na-1][self.NX-1]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0)
        
    def bestResponse(self, peakPr, offpeakPr, cPrice, fPrice):
        # best response function
        # peakPr : peak price vector
        # offpeakPr : offpeak price vector
        # fPr : vector of fuel prices
        runGain = gp.LinExpr()
        entryGain = gp.LinExpr()
        exitGain = gp.LinExpr()
        curval = 0
        for i in range(self.Nt-1):
            for j in range(self.Na):
                H = self.dX*self.dt*self.da*np.exp(-self.rho*(self.T[i+1]))*(pcoef*self.gain(peakPr[i+1],cPrice[i+1],fPrice[:,i+1])+opcoef*self.gain(offpeakPr[i+1],cPrice[i+1], fPrice[:,i+1]))
                runGain.addTerms(H,self.m[i][j])
                curval = curval + np.sum(H*self.m_[i+1][j])
                H = -self.fCost*self.dX*self.dt*self.da*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
                entryGain.addTerms(H,self.muhat[i][j])
                curval = curval + np.sum(H*self.muhat_[i+1][j])
                H = self.sCost*self.dX*self.dt*self.da*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
                exitGain.addTerms(H,self.mu[i][j])
                curval = curval + np.sum(H*self.mu_[i+1][j])
            
       
        obj = runGain+entryGain+exitGain
        
        
        self.model.setObjective(obj,GRB.MAXIMIZE)
        self.model.update()
        
        self.model.optimize()
        
        #print(self.model.objVal)
        
        if self.model.SolCount ==0:
            print('no solution')
        sol_m = [[[self.m[j][z][i].X for i in range(self.NX)] for z in range(self.Na)] for j in range(self.Nt-1)]
        sol_mhat = [[[self.mhat[j][z][i].X for i in range(self.NX)] for z in range(self.Na)] for j in range(self.Nt-1)]
        sol_mu = [[[self.mu[j][z][i].X for i in range(self.NX)]for z in range(self.Na)] for j in range(self.Nt-1)]
        sol_muhat = [[[self.muhat[j][z][i].X for i in range(self.NX)]for z in range(self.Na)]  for j in range(self.Nt-1)]
        sol_mtau = [[self.mtau[j][i].X for i in range(self.NX)]for j in range(self.Nt-1)]
        sol_mutau = [[self.mutau[j][i].X for i in range(self.NX)]  for j in range(self.Nt-1)]

        ob_func = obj.getValue()- curval
        return ob_func, curval, np.array(sol_m),np.array(sol_mhat),np.array(sol_mu),np.array(sol_muhat),np.array(sol_mtau),np.array(sol_mutau)

    def update(self,weight,m,mhat,mu,muhat,mtau,mutau):
        # density update with given weight
        self.m_[1:,:,:] = (1.-weight)*self.m_[1:,:,:]+weight*m
        self.mhat_[1:,:,:] = (1.-weight)*self.mhat_[1:,:,:]+weight*mhat
        self.mu_[1:,:,:] = (1.-weight)*self.mu_[1:,:,:]+weight*mu
        self.muhat_[1:,:,:] = (1.-weight)*self.muhat_[1:,:,:]+weight*muhat
        self.mtau_[1:,:] = (1.-weight)*self.mtau_[1:,:]+weight*mtau
        self.mutau_[1:,:] = (1.-weight)*self.mutau_[1:,:]+weight*mutau
    
    
    
    def capacity(self):
        return np.sum(np.sum(self.m_,axis=1),axis=1)*self.dX*self.da
    def pot_capacity(self):
        return np.sum(np.sum(self.mhat_,axis=1),axis=1)*self.dX*self.da
    def exit_measure(self):
        return np.sum(np.sum(self.mu_,axis=1),axis=1)*self.dX*self.da
    def entry_measure(self):
        return np.sum(np.sum(self.muhat_,axis=1),axis=1)*self.dX*self.da



class Conventional(Agent):
# Base class for conventional producer
    epsilon = 0.5 # parameter of the supply function
    def __init__(self,name,cp,ap):
        Agent.__init__(self,name,cp,ap)
        self.cTax = ap['emissions']
        self.fuel = ap['fuel']
        self.cFuel = ap['cFuel']
        kappa = ap['mean reversion']
        theta = ap['long term mean']
        stdIn = ap['standard deviation']
        delta = stdIn*np.sqrt(2.*kappa/theta)
        V=1.+delta*delta*self.X*self.dt/(self.dX*self.dX)+self.dt/self.da
        V0=1.+delta*delta*self.X*self.dt/(self.dX*self.dX)
        V1 =-delta*delta*self.X*self.dt/(2*self.dX*self.dX)+kappa*(theta-self.X)*self.dt/(2*self.dX)
        V2=-delta*delta*self.X*self.dt/(2*self.dX*self.dX)-kappa*(theta-self.X)*self.dt/(2*self.dX)
        alpha = (theta/stdIn)*(theta/stdIn)
        bet = theta/stdIn/stdIn
        
        indens=np.zeros((self.Na,self.NX))
        indenshat=np.zeros((self.Na,self.NX))

        for i in range(len(indens)):
            indens[i] = ap['initial capacity']*bet*gamma.pdf(bet*self.X,alpha)/self.da/self.Na
            indenshat[i] = ap['potential capacity']*bet*gamma.pdf(bet*self.X,alpha)/self.da/self.Na
        
        self.preCalc(indens,indenshat,V,V0,V1,V2)
    def G(self,x):
        # Gain function
        return (self.epsilon/2+(x-self.epsilon))*(x>self.epsilon)+x*x/2/self.epsilon*(x>0)*(x<=self.epsilon)
    def F(self,x):
        # Supply function
        return (x-self.epsilon>0)+x/self.epsilon*(x>0)*(x<=self.epsilon)
    def gain(self,p, cp, fp):
        return (convcoef*self.G(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp) - self.rCost)
    def offer(self,p,cp, fp, t):
        return sum(self.F(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp)*np.sum(self.m_[t,self.Amin:self.Amax,:],axis=0))*self.dX*self.da
    def ioffer(self,p,cp,fp,t):
        return sum(self.G(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp)*np.sum(self.m_[t,self.Amin:self.Amax,:],axis=0))*self.dX*self.da
    def full_offer(self,price, cPrice, fPrice):
        # agent supply for given price level
        res = np.zeros(self.Nt)
        for i in range(self.Nt):
            res[i] = self.offer(price[i], cPrice[i], fPrice[:,i],i)
        return res





class Renewable(Agent):
    def __init__(self,name,cp,ap):
        Agent.__init__(self,name,cp,ap)
        kappa = ap['mean reversion']
        theta = ap['long term mean']
        stdIn = ap['standard deviation']
        delta = stdIn*np.sqrt(2.*kappa/(theta*(1-theta)-stdIn*stdIn))
        V=1.+delta*delta*self.X*(1-self.X)*self.dt/(self.dX*self.dX)+self.dt/self.da
        V0=1.+delta*delta*self.X*(1-self.X)*self.dt/(self.dX*self.dX)
        V1 = -delta*delta*self.X*(1.-self.X)*self.dt/(2*self.dX*self.dX)+kappa*(theta-self.X)*self.dt/(2*self.dX)
        V2 = -delta*delta*self.X*(1.-self.X)*self.dt/(2*self.dX*self.dX)-kappa*(theta-self.X)*self.dt/(2*self.dX)
        alpha = theta*(theta*(1.-theta)/stdIn/stdIn-1.)
        bet = (1.-theta)*(theta*(1.-theta)/stdIn/stdIn-1.)
        indens=np.zeros((self.Na,self.NX))
        indenshat=np.zeros((self.Na,self.NX))

        for i in range(len(indens)):
            #The sum should be initial capacity
            indens[i] = ap['initial capacity']*beta.pdf(self.X,alpha,bet)/self.da/self.Na
            indenshat[i] = ap['potential capacity']*beta.pdf(self.X,alpha,bet)/self.da/self.Na
        self.preCalc(indens,indenshat,V,V0,V1,V2)
    def gain(self,p,cp,fp):
        return convcoef*p*self.X - self.rCost
    def offer(self,t):
        return sum(self.X*np.sum(self.m_[t,self.Amin:self.Amax,:],axis=0))*self.dX*self.da
    def full_offer(self):
        # agent supply for given price level
        res = np.zeros(self.Nt)
        for i in range(self.Nt):
            res[i] = self.offer(i)
        return res


class Simulation:
    # main class for performing the simulation
    def __init__(self, cagents, ragents, cp):
        # agents: list of agent class instances
        # cp : common parameters
        self.cagents = cagents# conventional
        self.ragents = ragents# renewable
        self.Nt = cp['Nt']
        self.T = np.linspace(cp['tmin'],cp['tmax'],self.Nt)
        self.pdemand = np.array(cp["demand"])*cp["demand ratio"]/(pcoef*cp["demand ratio"]+opcoef)
        self.opdemand = np.array(cp["demand"])/(pcoef*cp["demand ratio"]+opcoef)
        self.Prp = np.zeros(self.Nt)
        self.Prop = np.zeros(self.Nt)
        self.Nfuels = cp['Nfuels']
        self.fTax = np.interp(self.T,cp['carbon tax'][0],cp['carbon tax'][1])
        self.acoef = np.array(cp['Fsupply'][0])
        self.bcoef = np.array(cp['Fsupply'][1])
        self.fPrice = np.zeros((self.Nfuels,self.Nt))

    def psibar(self,x):
        return np.sum(self.bcoef*(x-self.acoef)**2/2.)

    def calcPrice(self):
        # compute price for given demand profile
        def opfunc(x,t):
            # x = [pp,pop,p1...pK]
        
            rdem = reduce(lambda a,b:a+b.offer(t),self.ragents,0)
    
            res = self.psibar(x[2:])
            for ag in self.cagents:
                res = res + pcoef*ag.ioffer(x[0],self.fTax[t],x[2:],t) + opcoef*ag.ioffer(x[1],self.fTax[t],x[2:],t)
            return res+pcoef*x[0]*(rdem-self.pdemand[t])+opcoef*x[1]*(rdem-self.opdemand[t])+pcoef*G0(x[0])+opcoef*G0(x[1])

        for j in range(self.Nt):
         
            x0 = np.zeros(self.Nfuels+2)
            x0[0] = self.Prp[j]
            x0[1] = self.Prop[j]
            x0[2:] = self.fPrice[:,j]
            bds = [(0,Pmax),(0,Pmax)]+[(0,None)]*self.Nfuels
            opres = minimize(lambda x:opfunc(x,j),x0,bounds=bds)
       
            self.Prp[j]=opres.x[0]
            self.Prop[j] = opres.x[1]
            self.fPrice[:,j] = opres.x[2:]
            #print(opres.x)

    def run(self,Niter,tol,power=1., shift=1):
        # run the simulation with maximum Niter iterations
        # the program will stop when the total increase of objective function is less than tol
        # power and shift are coefficients in the weight update formula
        conv = np.zeros(Niter)
        start = time.time()
        for i in range(Niter):
        #for i in range(1):
            self.calcPrice()
            #print(self.Prop)
            weight = np.power(1./(i+shift),power)
            print("Iteration",i)
            message = "Weight: {:.4f}".format(weight)
            obtot = 0
            for a in self.ragents:
                ob, val, m,mhat,mu,muhat,mtau,mutau = a.bestResponse(self.Prp,self.Prop,self.fTax,self.fPrice)
                a.update(weight,m,mhat,mu,muhat,mtau,mutau)
                message = message+"; "+a.name+": {:.2f}".format(ob)
                obtot = obtot+ob
        
            for a in self.cagents:
                ob, val, m,mhat,mu,muhat,mtau,mutau = a.bestResponse(self.Prp,self.Prop,self.fTax,self.fPrice)
                a.update(weight,m,mhat,mu,muhat,mtau,mutau)
                message = message+"; "+a.name+": {:.2f}".format(ob)
                obtot = obtot+ob
           
            message = message + "; Total: {:.2f}".format(obtot)
            conv[i] = obtot
            print(message)
            if(obtot<tol):
                Niter = i
                break
        self.calcPrice()
        end = time.time()
        return conv, end-start, Niter

    def write(self, scenario_name):
        # write simulation output into a file scenario_name
        output = {"time": self.cagents[0].T, "peak price":self.Prp,"offpeak price":self.Prop,
                  "peak demand":self.pdemand, "offpeak demand":self.opdemand}
        for a in self.cagents:
            output[a.name+" capacity"] = a.capacity()
            output[a.name+" potential capacity"] = a.pot_capacity()
            output[a.name+" exit measure"] =  a.exit_measure()
            output[a.name+" entry measure"] = a.entry_measure()
            output[a.name+" peak supply"] = a.full_offer(self.Prp,self.fTax, self.fPrice)
            output[a.name+" offpeak supply"] = a.full_offer(self.Prop,self.fTax,self.fPrice)
        for a in self.ragents:
            output[a.name+" capacity"] = a.capacity()
            output[a.name+" potential capacity"] = a.pot_capacity()
            output[a.name+" exit measure"] = a.exit_measure()
            output[a.name+" entry measure"] = a.entry_measure()
            output[a.name+" peak supply"] = a.full_offer()
            output[a.name+" offpeak supply"] = a.full_offer()
        for i in range(self.Nfuels):
            output["Fuel "+str(i)] = self.fPrice[i,:]
        df = pd.DataFrame.from_dict(output)
        df.to_csv(scenario_name+'.csv')
        return output


def getpar(fname):
    # service function: extract parameter dictionary from file
    with open(fname) as f:
        data = f.read()
    return eval(data)

# %%
import os as os
scenario_name = "test" # this will be the name of the output file & folder

cp = getpar("common_params.py")

# list of conventional agents; modify this to add / remove agent types
cagents = [Conventional('Coal',cp,getpar('coal.py')),
          Conventional('Gas',cp,getpar('gas.py'))]

# list of renewable agents; modify this to add / remove agent types
ragents = [Renewable('Renewable',cp,getpar('renewable.py'))]
Niter = cp['iterations']
#Niter=2
tol = cp['tolerance']
sim = Simulation(cagents,ragents,cp)
conv, elapsed, Nit = sim.run(Niter, tol, cp['power'], cp['offset'])
# Out:
# Iteration 0
# Weight: 0.2759; Renewable: 194533.07; Coal: 335457.43; Gas: 373699.22; Total: 903689.72
# Iteration 1
# Weight: 0.2385; Renewable: 114251.90; Coal: 183486.76; Gas: 180578.69; Total: 478317.35
# Iteration 2
# Weight: 0.2108; Renewable: 58483.53; Coal: 25333.73; Gas: 22904.59; Total: 106721.85
# Iteration 3
# Weight: 0.1895; Renewable: 45844.53; Coal: 7781.10; Gas: 7572.72; Total: 61198.36
# Iteration 4
# Weight: 0.1724; Renewable: 35675.44; Coal: 5616.14; Gas: 4805.40; Total: 46096.97
# Iteration 5
# Weight: 0.1585; Renewable: 28856.40; Coal: 4176.57; Gas: 3429.61; Total: 36462.58
# Iteration 6
# Weight: 0.1469; Renewable: 23801.41; Coal: 3358.75; Gas: 2651.30; Total: 29811.46
# Iteration 7
# Weight: 0.1370; Renewable: 20130.97; Coal: 2615.68; Gas: 2154.14; Total: 24900.79
# Iteration 8
# Weight: 0.1285; Renewable: 17139.34; Coal: 2217.42; Gas: 1825.32; Total: 21182.07
# Iteration 9
# Weight: 0.1211; Renewable: 14836.75; Coal: 1870.15; Gas: 1565.89; Total: 18272.79
# Iteration 10
# Weight: 0.1146; Renewable: 12937.61; Coal: 1631.46; Gas: 1380.42; Total: 15949.50
# Iteration 11
# Weight: 0.1088; Renewable: 11418.52; Coal: 1403.47; Gas: 1217.72; Total: 14039.72
# Iteration 12
# Weight: 0.1037; Renewable: 10127.07; Coal: 1248.13; Gas: 1086.70; Total: 12461.91
# Iteration 13
# Weight: 0.0990; Renewable: 9060.63; Coal: 1100.04; Gas: 971.98; Total: 11132.65
# Iteration 14
# Weight: 0.0948; Renewable: 8142.00; Coal: 983.86; Gas: 877.77; Total: 10003.64
# Iteration 15
# Weight: 0.0910; Renewable: 7357.17; Coal: 884.55; Gas: 793.90; Total: 9035.61
# Iteration 16
# Weight: 0.0875; Renewable: 6675.87; Coal: 799.99; Gas: 722.04; Total: 8197.90
# Iteration 17
# Weight: 0.0843; Renewable: 6083.11; Coal: 727.49; Gas: 658.13; Total: 7468.73
# Iteration 18
# Weight: 0.0814; Renewable: 5560.93; Coal: 665.73; Gas: 603.31; Total: 6829.96
# Iteration 19
# Weight: 0.0787; Renewable: 5103.49; Coal: 609.27; Gas: 553.41; Total: 6266.17
# Iteration 20
# Weight: 0.0761; Renewable: 4696.59; Coal: 560.40; Gas: 510.17; Total: 5767.16
# Iteration 21
# Weight: 0.0738; Renewable: 4335.84; Coal: 516.49; Gas: 470.89; Total: 5323.22
# Iteration 22
# Weight: 0.0716; Renewable: 4012.02; Coal: 478.24; Gas: 436.55; Total: 4926.82
# Iteration 23
# Weight: 0.0695; Renewable: 3723.17; Coal: 443.03; Gas: 404.96; Total: 4571.16
# Iteration 24
# Weight: 0.0676; Renewable: 3460.43; Coal: 412.90; Gas: 377.61; Total: 4250.94
# Iteration 25
# Weight: 0.0658; Renewable: 3225.32; Coal: 383.98; Gas: 351.55; Total: 3960.84
# Iteration 26
# Weight: 0.0641; Renewable: 3011.49; Coal: 358.28; Gas: 328.34; Total: 3698.11
# Iteration 27
# Weight: 0.0625; Renewable: 2817.45; Coal: 334.94; Gas: 307.21; Total: 3459.59
# Iteration 28
# Weight: 0.0610; Renewable: 2640.02; Coal: 313.96; Gas: 288.17; Total: 3242.16
# Iteration 29
# Weight: 0.0595; Renewable: 2478.45; Coal: 294.72; Gas: 270.56; Total: 3043.73
# Iteration 30
# Weight: 0.0582; Renewable: 2329.76; Coal: 277.28; Gas: 254.80; Total: 2861.84
# Iteration 31
# Weight: 0.0569; Renewable: 2193.96; Coal: 260.83; Gas: 239.65; Total: 2694.43
# Iteration 32
# Weight: 0.0556; Renewable: 2068.35; Coal: 245.90; Gas: 226.11; Total: 2540.36
# Iteration 33
# Weight: 0.0545; Renewable: 1952.97; Coal: 232.08; Gas: 213.47; Total: 2398.52
# Iteration 34
# Weight: 0.0534; Renewable: 1846.25; Coal: 219.19; Gas: 201.76; Total: 2267.20
# Iteration 35
# Weight: 0.0523; Renewable: 1747.40; Coal: 207.44; Gas: 190.99; Total: 2145.82
# Iteration 36
# Weight: 0.0513; Renewable: 1655.77; Coal: 196.54; Gas: 180.98; Total: 2033.28
# Iteration 37
# Weight: 0.0503; Renewable: 1570.68; Coal: 186.38; Gas: 171.68; Total: 1928.73
# Iteration 38
# Weight: 0.0493; Renewable: 1491.37; Coal: 177.01; Gas: 163.12; Total: 1831.50
# Iteration 39
# Weight: 0.0484; Renewable: 1417.61; Coal: 168.28; Gas: 155.04; Total: 1740.93
# Iteration 40
# Weight: 0.0476; Renewable: 1348.78; Coal: 160.06; Gas: 147.50; Total: 1656.34
# Iteration 41
# Weight: 0.0468; Renewable: 1284.51; Coal: 152.39; Gas: 140.48; Total: 1577.38
# Iteration 42
# Weight: 0.0460; Renewable: 1224.27; Coal: 145.26; Gas: 133.92; Total: 1503.45
# Iteration 43
# Weight: 0.0452; Renewable: 1167.92; Coal: 138.53; Gas: 127.75; Total: 1434.20
# Iteration 44
# Weight: 0.0444; Renewable: 1115.07; Coal: 132.22; Gas: 121.96; Total: 1369.24
# Iteration 45
# Weight: 0.0437; Renewable: 1065.45; Coal: 126.30; Gas: 116.54; Total: 1308.29
# Iteration 46
# Weight: 0.0430; Renewable: 1018.73; Coal: 120.77; Gas: 111.44; Total: 1250.94
# Iteration 47
# Weight: 0.0424; Renewable: 974.80; Coal: 115.56; Gas: 106.65; Total: 1197.01
# Iteration 48
# Weight: 0.0417; Renewable: 933.42; Coal: 110.63; Gas: 102.12; Total: 1146.17
# Iteration 49
# Weight: 0.0411; Renewable: 894.42; Coal: 106.01; Gas: 97.89; Total: 1098.32
# Iteration 50
# Weight: 0.0405; Renewable: 857.57; Coal: 101.60; Gas: 93.87; Total: 1053.05
# Iteration 51
# Weight: 0.0399; Renewable: 822.81; Coal: 97.50; Gas: 90.09; Total: 1010.40
# Iteration 52
# Weight: 0.0394; Renewable: 789.85; Coal: 93.57; Gas: 86.45; Total: 969.87
# Iteration 53
# Weight: 0.0388; Renewable: 758.71; Coal: 89.89; Gas: 83.04; Total: 931.64
# Iteration 54
# Weight: 0.0383; Renewable: 729.21; Coal: 86.37; Gas: 79.81; Total: 895.39
# Iteration 55
# Weight: 0.0378; Renewable: 701.20; Coal: 83.07; Gas: 76.77; Total: 861.04
# Iteration 56
# Weight: 0.0373; Renewable: 674.68; Coal: 79.92; Gas: 73.86; Total: 828.46
# Iteration 57
# Weight: 0.0368; Renewable: 649.50; Coal: 76.91; Gas: 71.08; Total: 797.49
# Iteration 58
# Weight: 0.0364; Renewable: 625.58; Coal: 74.05; Gas: 68.47; Total: 768.10
# Iteration 59
# Weight: 0.0359; Renewable: 602.81; Coal: 71.37; Gas: 66.01; Total: 740.19
# Iteration 60
# Weight: 0.0355; Renewable: 581.12; Coal: 68.80; Gas: 63.72; Total: 713.64
# Iteration 61
# Weight: 0.0350; Renewable: 560.51; Coal: 66.37; Gas: 61.39; Total: 688.26
# Iteration 62
# Weight: 0.0346; Renewable: 540.86; Coal: 64.02; Gas: 59.22; Total: 664.10
# Iteration 63
# Weight: 0.0342; Renewable: 522.14; Coal: 61.79; Gas: 57.16; Total: 641.09
# Iteration 64
# Weight: 0.0338; Renewable: 504.27; Coal: 59.66; Gas: 55.21; Total: 619.14
# Iteration 65
# Weight: 0.0334; Renewable: 487.23; Coal: 57.63; Gas: 53.34; Total: 598.20
# Iteration 66
# Weight: 0.0330; Renewable: 470.94; Coal: 55.69; Gas: 51.56; Total: 578.19
# Iteration 67
# Weight: 0.0327; Renewable: 455.37; Coal: 53.86; Gas: 49.88; Total: 559.10
# Iteration 68
# Weight: 0.0323; Renewable: 440.50; Coal: 52.12; Gas: 48.30; Total: 540.91
# Iteration 69
# Weight: 0.0320; Renewable: 426.21; Coal: 50.43; Gas: 46.70; Total: 523.34
# Iteration 70
# Weight: 0.0316; Renewable: 412.58; Coal: 48.80; Gas: 45.20; Total: 506.59
# Iteration 71
# Weight: 0.0313; Renewable: 399.54; Coal: 47.24; Gas: 43.75; Total: 490.53
# Iteration 72
# Weight: 0.0310; Renewable: 387.04; Coal: 45.76; Gas: 42.38; Total: 475.17
# Iteration 73
# Weight: 0.0306; Renewable: 375.05; Coal: 44.34; Gas: 41.06; Total: 460.45
# Iteration 74
# Weight: 0.0303; Renewable: 363.55; Coal: 42.98; Gas: 39.81; Total: 446.34
# Iteration 75
# Weight: 0.0300; Renewable: 352.52; Coal: 41.67; Gas: 38.59; Total: 432.79
# Iteration 76
# Weight: 0.0297; Renewable: 341.93; Coal: 40.44; Gas: 37.49; Total: 419.85
# Iteration 77
# Weight: 0.0294; Renewable: 331.77; Coal: 39.23; Gas: 36.41; Total: 407.41
# Iteration 78
# Weight: 0.0292; Renewable: 321.99; Coal: 38.06; Gas: 35.27; Total: 395.32
# Iteration 79
# Weight: 0.0289; Renewable: 312.60; Coal: 36.94; Gas: 34.23; Total: 383.77
# Iteration 80
# Weight: 0.0286; Renewable: 303.57; Coal: 35.87; Gas: 33.25; Total: 372.68
# Iteration 81
# Weight: 0.0283; Renewable: 294.88; Coal: 34.84; Gas: 32.33; Total: 362.05
# Iteration 82
# Weight: 0.0281; Renewable: 286.52; Coal: 33.85; Gas: 31.38; Total: 351.74
# Iteration 83
# Weight: 0.0278; Renewable: 278.47; Coal: 32.91; Gas: 30.51; Total: 341.89
# Iteration 84
# Weight: 0.0276; Renewable: 270.72; Coal: 32.01; Gas: 29.75; Total: 332.48
# Iteration 85
# Weight: 0.0273; Renewable: 263.25; Coal: 31.12; Gas: 28.84; Total: 323.20
# Iteration 86
# Weight: 0.0271; Renewable: 256.05; Coal: 30.25; Gas: 28.08; Total: 314.38
# Iteration 87
# Weight: 0.0269; Renewable: 249.11; Coal: 29.43; Gas: 27.29; Total: 305.83
# Iteration 88
# Weight: 0.0266; Renewable: 242.42; Coal: 28.64; Gas: 26.56; Total: 297.62
# Iteration 89
# Weight: 0.0264; Renewable: 235.98; Coal: 27.87; Gas: 25.85; Total: 289.70
# Iteration 90
# Weight: 0.0262; Renewable: 229.75; Coal: 27.14; Gas: 25.16; Total: 282.04
# Iteration 91
# Weight: 0.0260; Renewable: 223.72; Coal: 26.43; Gas: 24.51; Total: 274.65
# Iteration 92
# Weight: 0.0257; Renewable: 217.91; Coal: 25.74; Gas: 23.87; Total: 267.52
# Iteration 93
# Weight: 0.0255; Renewable: 212.30; Coal: 25.08; Gas: 23.26; Total: 260.64
# Iteration 94
# Weight: 0.0253; Renewable: 206.88; Coal: 24.44; Gas: 22.66; Total: 253.98
# Iteration 95
# Weight: 0.0251; Renewable: 201.65; Coal: 23.82; Gas: 22.09; Total: 247.56
# Iteration 96
# Weight: 0.0249; Renewable: 196.58; Coal: 23.22; Gas: 21.55; Total: 241.36
# Iteration 97
# Weight: 0.0247; Renewable: 191.68; Coal: 22.64; Gas: 21.00; Total: 235.32
# Iteration 98
# Weight: 0.0245; Renewable: 186.94; Coal: 22.08; Gas: 20.48; Total: 229.50
# Iteration 99
# Weight: 0.0243; Renewable: 182.35; Coal: 21.54; Gas: 19.97; Total: 223.86
# Iteration 100
# Weight: 0.0242; Renewable: 177.91; Coal: 21.01; Gas: 19.49; Total: 218.42
# Iteration 101
# Weight: 0.0240; Renewable: 173.61; Coal: 20.50; Gas: 19.02; Total: 213.13
# Iteration 102
# Weight: 0.0238; Renewable: 169.45; Coal: 20.01; Gas: 18.56; Total: 208.02
# Iteration 103
# Weight: 0.0236; Renewable: 165.41; Coal: 19.53; Gas: 18.12; Total: 203.07
# Iteration 104
# Weight: 0.0234; Renewable: 161.51; Coal: 19.07; Gas: 17.72; Total: 198.30
# Iteration 105
# Weight: 0.0233; Renewable: 157.73; Coal: 18.63; Gas: 17.29; Total: 193.65
# Iteration 106
# Weight: 0.0231; Renewable: 154.05; Coal: 18.19; Gas: 16.89; Total: 189.13
# Iteration 107
# Weight: 0.0229; Renewable: 150.48; Coal: 17.77; Gas: 16.52; Total: 184.78
# Iteration 108
# Weight: 0.0228; Renewable: 147.03; Coal: 17.36; Gas: 16.12; Total: 180.52
# Iteration 109
# Weight: 0.0226; Renewable: 143.68; Coal: 16.97; Gas: 15.75; Total: 176.39
# Iteration 110
# Weight: 0.0225; Renewable: 140.44; Coal: 16.59; Gas: 15.39; Total: 172.41
# Iteration 111
# Weight: 0.0223; Renewable: 137.28; Coal: 16.21; Gas: 15.04; Total: 168.53
# Iteration 112
# Weight: 0.0222; Renewable: 134.22; Coal: 15.84; Gas: 14.73; Total: 164.79
# Iteration 113
# Weight: 0.0220; Renewable: 131.24; Coal: 15.49; Gas: 14.39; Total: 161.12
# Iteration 114
# Weight: 0.0219; Renewable: 128.35; Coal: 15.15; Gas: 14.06; Total: 157.57
# Iteration 115
# Weight: 0.0217; Renewable: 125.55; Coal: 14.82; Gas: 13.77; Total: 154.14
# Iteration 116
# Weight: 0.0216; Renewable: 122.82; Coal: 14.50; Gas: 13.46; Total: 150.78
# Iteration 117
# Weight: 0.0214; Renewable: 120.18; Coal: 14.18; Gas: 13.17; Total: 147.53
# Iteration 118
# Weight: 0.0213; Renewable: 117.60; Coal: 13.88; Gas: 12.89; Total: 144.37
# Iteration 119
# Weight: 0.0211; Renewable: 115.09; Coal: 13.59; Gas: 12.61; Total: 141.29
# Iteration 120
# Weight: 0.0210; Renewable: 112.66; Coal: 13.30; Gas: 12.34; Total: 138.30
# Iteration 121
# Weight: 0.0209; Renewable: 110.29; Coal: 13.02; Gas: 12.08; Total: 135.39
# Iteration 122
# Weight: 0.0207; Renewable: 107.99; Coal: 12.75; Gas: 11.83; Total: 132.56
# Iteration 123
# Weight: 0.0206; Renewable: 105.75; Coal: 12.48; Gas: 11.59; Total: 129.82
# Iteration 124
# Weight: 0.0205; Renewable: 103.57; Coal: 12.23; Gas: 11.37; Total: 127.16
# Iteration 125
# Weight: 0.0204; Renewable: 101.44; Coal: 11.98; Gas: 11.12; Total: 124.53
# Iteration 126
# Weight: 0.0202; Renewable: 99.38; Coal: 11.73; Gas: 10.91; Total: 122.02
# Iteration 127
# Weight: 0.0201; Renewable: 97.37; Coal: 11.50; Gas: 10.67; Total: 119.54
# Iteration 128
# Weight: 0.0200; Renewable: 95.41; Coal: 11.26; Gas: 10.46; Total: 117.13
# Iteration 129
# Weight: 0.0199; Renewable: 93.50; Coal: 11.04; Gas: 10.24; Total: 114.78
# Iteration 130
# Weight: 0.0198; Renewable: 91.64; Coal: 10.82; Gas: 10.04; Total: 112.50
# Iteration 131
# Weight: 0.0196; Renewable: 89.83; Coal: 10.60; Gas: 9.85; Total: 110.28
# Iteration 132
# Weight: 0.0195; Renewable: 88.06; Coal: 10.40; Gas: 9.65; Total: 108.11
# Iteration 133
# Weight: 0.0194; Renewable: 86.36; Coal: 10.20; Gas: 9.48; Total: 106.05
# Iteration 134
# Weight: 0.0193; Renewable: 84.67; Coal: 10.00; Gas: 9.29; Total: 103.96
# Iteration 135
# Weight: 0.0192; Renewable: 83.03; Coal: 9.80; Gas: 9.10; Total: 101.94
# Iteration 136
# Weight: 0.0191; Renewable: 81.45; Coal: 9.61; Gas: 8.92; Total: 99.98

# %%
print('Elapsed time: ', elapsed)
out = sim.write(scenario_name)
# Out:
# Elapsed time:  131.62580108642578

# %%
try:
    os.mkdir(scenario_name)
except FileExistsError:
    print('Directory already exists')
os.system("cp common_params.py "+scenario_name+"/common_params.py")

# parameter files are copied to output directory; change this if you change agent types
os.system("cp coal.py "+scenario_name+"/coal.py")
os.system("cp gas.py "+scenario_name+"/gas.py")
os.system("cp renewable.py "+scenario_name+"/renewable.py")

os.system("cp "+scenario_name+'.csv '+scenario_name+"/"+scenario_name+".csv")


plt.figure(figsize=(14,5))
plt.subplot(121)
plt.plot(2018+out['time'], out['peak price'], label='peak price')
plt.plot(2018+out['time'], out['offpeak price'], label='offpeak price')
plt.legend()
plt.title('Electricity price')
plt.subplot(122)

# Plotting the capacity for each agent type; modify this if you change agent types
plt.plot(2018+out['time'], out['Coal capacity'], label='Coal capacity')
plt.plot(2018+out['time'], out['Gas capacity'],label='Gas capacity')
plt.plot(2018+out['time'], out['Renewable capacity'], label='Renewable capacity')
plt.legend()
plt.title('Installed capacity')
plt.savefig(scenario_name+"/"+'price_capacity.pdf', format='pdf')
#plt.suptitle("Na=5")
#plt.savefig('Na=5.pdf', format='pdf')


plt.figure(figsize=(14, 5))
plt.subplot(121)
plt.plot(2018+out['time'], sim.pdemand, label='peak demand')
plt.plot(2018+out['time'], sim.opdemand, label='offpeak demand')
plt.legend()
plt.title('Electricity demand')
plt.subplot(122)

# Plotting the fuel prices; modify this if you change fuel types
plt.plot(2018+out['time'], out['Fuel 0'], label='Coal price')
plt.plot(2018+out['time'], out['Fuel 1'], label='Gas price')
plt.legend()
plt.title('Fuel price')
#plt.plot(2018+out['time'],np.interp(out['time'],cp["carbon tax"][0],cp["carbon tax"][1]))
plt.savefig(scenario_name+"/"+'demand_fuelprice.pdf',format='pdf')


plt.figure(figsize=(14,5))
plt.subplot(121)

# Plotting the supply for each agent; modify this if you change agent types
plt.bar(2018+out['time'],out['Coal peak supply'],width=0.25,label='Coal supply')
plt.bar(2018+out['time'],out['Gas peak supply'],width=0.25,
        bottom=out['Coal peak supply'],label='Gas supply')
plt.bar(2018+out['time'],out['Renewable peak supply'],width=0.25,
        bottom=out['Gas peak supply']+out['Coal peak supply'],label='Renewable supply')
#plt.ylim([0,80])
plt.title('Conventional/ renewable peak supply, GW')
plt.legend()
plt.subplot(122)
plt.bar(2018+out['time'],out['Coal offpeak supply'],width=0.5,label='Coal supply')
plt.bar(2018+out['time'],out['Gas offpeak supply'],width=0.25,
        bottom=out['Coal offpeak supply'],label='Gas supply')
plt.bar(2018+out['time'],out['Renewable offpeak supply'],width=0.25,
        bottom=out['Gas offpeak supply']+out['Coal offpeak supply'],label='Renewable supply')

plt.title('Conventional/ renewable off-peak supply, GW')

#plt.ylim([0,80])


plt.legend()
plt.savefig(scenario_name+"/"+'supply.pdf',format='pdf')
plt.show()



print('Elapsed time: ', elapsed)
# Out:
# Directory already exists
# Elapsed time:  131.62580108642578
