# %%
import numpy as np
import math
from scipy.stats import norm
import matplotlib
import matplotlib.pyplot as plt
import time
from scipy.optimize import root_scalar, minimize
from scipy.stats import gamma
from scipy.stats import beta
from scipy.linalg import block_diag
import random
import pandas as pd
from functools import reduce

import gurobipy as gp
from gurobipy import GRB

# Constants
# peak hours
pcoef = 65./168
# off-peak hours
opcoef = 103./168
# conversion of hourly revenue per MW into annual revenue per kW
convcoef = 24.*365.25/1000.
# baseline supply
def F0(X):
    return 17.5*X/150.
# Integrated baseline supply function
def G0(X):
    return 17.5*X*X/300.
# price cap
Pmax = 200


class Agent: # Base class for any producer

    def __init__(self,name,cp,ap):
        # name : name of agent
        # cp : common parameters
        # ap : agent parameters
        # described in derived classes
        self.name = name
        self.Nt = cp['Nt']
        self.NX = ap['NX']
        #self.NX = 10
        #self.Nt=5
        #self.NX=
        
        
        self.dX = 1.*(ap['Xmax']-ap['Xmin'])/(self.NX-1)
        self.dt = 1.*(cp['tmax']-cp['tmin'])/(self.Nt-1)
        self.X = np.linspace(ap['Xmin'],ap['Xmax'],self.NX)
        self.T = np.linspace(cp['tmin'],cp['tmax'],self.Nt)
        self.rho = ap['discount rate']
        self.gamma0 = ap['depreciation rate']
        self.rCost = ap['running cost']
        self.fCost = ap['fixed cost']
        self.sCost = ap['scrap value']
        self.tmax = cp['tmax']


class Conventional_2d(Agent):
# Base class for conventional producer
    epsilon = 0.5 # parameter of the supply function
    def __init__(self,name,cp,ap):
        Agent.__init__(self,name,cp,ap)
        self.cTax = ap['emissions']
        self.fuel = ap['fuel']
        self.cFuel = ap['cFuel']
        kappa = ap['mean reversion']
        theta = ap['long term mean']
        stdIn = ap['standard deviation']
        delta = stdIn*np.sqrt(2.*kappa/theta)
        self.m_ = np.zeros((self.Nt,self.NX))
        self.mhat_ = np.zeros((self.Nt,self.NX))
        self.mu_ = np.zeros((self.Nt,self.NX))
        self.muhat_ = np.zeros((self.Nt,self.NX))
        V=1.+delta*delta*self.X*self.dt/(self.dX*self.dX)
        #print(V)
        V1 =-delta*delta*self.X*self.dt/(2*self.dX*self.dX)+kappa*(theta-self.X)*self.dt/(2*self.dX)
        #print(V1)
        V2=-delta*delta*self.X*self.dt/(2*self.dX*self.dX)-kappa*(theta-self.X)*self.dt/(2*self.dX)
        alpha = (theta/stdIn)*(theta/stdIn)
        bet = theta/stdIn/stdIn
        indens = ap['initial capacity']*bet*gamma.pdf(bet*self.X,alpha)
        indenshat = ap['potential capacity']*bet*gamma.pdf(bet*self.X,alpha)
        self.preCalc(indens,indenshat,V,V1,V2)
    def G(self,x):
        # Gain function
        return (self.epsilon/2+(x-self.epsilon))*(x>self.epsilon)+x*x/2/self.epsilon*(x>0)*(x<=self.epsilon)
    def F(self,x):
        # Supply function
        return (x-self.epsilon>0)+x/self.epsilon*(x>0)*(x<=self.epsilon)
    def gain(self,p, cp, fp):
        return (convcoef*self.G(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp) - self.rCost)
    def offer(self,p,cp, fp, t):
        return sum(self.F(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp)*self.m_[t,:])*self.dX
    def ioffer(self,p,cp,fp,t):
        return sum(self.G(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp)*self.m_[t,:])*self.dX
    def full_offer(self,price, cPrice, fPrice):
        # agent supply for given price level
        res = np.zeros(self.Nt)
        for i in range(self.Nt):
            res[i] = self.offer(price[i], cPrice[i], fPrice[:,i],i)
        return res

    def preCalc(self,indens,indenshat,V,V1,V2):
        # Some technical preliminary computations
        self.m_[0,:] = indens[:]
        #print(indens)
        self.mhat_[0,:] = indenshat[:]
        #print(indenshat)
        with gp.Env(empty=True) as env:
            env.setParam('OutputFlag', 0)
            env.start()
            self.model = gp.Model(env=env)
        self.mhat= [[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.m = [[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.muhat = [[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.mu = [[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        for i in range(0,self.Nt-2):
            for j in range(1,self.NX-1):
                expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],self.dt,-self.dt,-1.],[self.m[i+1][j],self.m[i+1][j+1],self.m[i+1][j-1],self.mu[i+1][j],self.muhat[i+1][j],self.m[i][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
               # print('expr=')
                #print(expr)
                
                expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],self.dt,-1.],[self.mhat[i+1][j],self.mhat[i+1][j+1],self.mhat[i+1][j-1],self.muhat[i+1][j],self.mhat[i][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                #print(expr)
            expr = gp.LinExpr([V[0],V1[1],self.dt,-self.dt,-1.],[self.m[i+1][0],self.m[i+1][1],self.mu[i+1][0],self.muhat[i+1][0],self.m[i][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],self.dt,-self.dt,-1.],[self.m[i+1][self.NX-1],self.m[i+1][self.NX-2],self.mu[i+1][self.NX-1],self.muhat[i+1][self.NX-1],self.m[i][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            expr = gp.LinExpr([V[0],V1[1],self.dt,-1.],[self.mhat[i+1][0],self.mhat[i+1][1],self.muhat[i+1][0],self.mhat[i][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],self.dt,-1.],[self.mhat[i+1][self.NX-1],self.mhat[i+1][self.NX-2],self.muhat[i+1][self.NX-1],self.mhat[i][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
        for j in range(1,self.NX-1):
            expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],self.dt,-self.dt],[self.m[0][j],self.m[0][j+1],self.m[0][j-1],self.mu[0][j],self.muhat[0][j]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[j])
            expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],self.dt],[self.mhat[0][j],self.mhat[0][j+1],self.mhat[0][j-1],self.muhat[0][j]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[j])
        expr = gp.LinExpr([V[0],V1[1],self.dt,-self.dt],[self.m[0][0],self.m[0][1],self.mu[0][0],self.muhat[0][0]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[0])
        expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],self.dt,-self.dt],[self.m[0][self.NX-1],self.m[0][self.NX-2],self.mu[0][self.NX-1],self.muhat[0][self.NX-1]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[self.NX-1])
        expr = gp.LinExpr([V[0],V1[1],self.dt],[self.mhat[0][0],self.mhat[0][1],self.muhat[0][0]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[0])
        expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],self.dt],[self.mhat[0][self.NX-1],self.mhat[0][self.NX-2],self.muhat[0][self.NX-1]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[self.NX-1])


    def bestResponse(self, peakPr, offpeakPr, cPrice, fPrice):
        # best response function
        # peakPr : peak price vector
        # offpeakPr : offpeak price vector
        # fPr : vector of fuel prices
        runGain = gp.LinExpr()
        entryGain = gp.LinExpr()
        exitGain = gp.LinExpr()
        curval = 0
        for i in range(self.Nt-1):
            H = self.dX*self.dt*np.exp(-self.rho*(self.T[i+1]))*(pcoef*self.gain(peakPr[i+1],cPrice[i+1],fPrice[:,i+1])+opcoef*self.gain(offpeakPr[i+1],cPrice[i+1], fPrice[:,i+1]))
            runGain.addTerms(H,self.m[i])
            #print(runGain)
            curval = curval + np.sum(H*self.m_[i+1,:])
            
            H = -self.fCost*self.dX*self.dt*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
            entryGain.addTerms(H,self.muhat[i])
            curval = curval + np.sum(H*self.muhat_[i+1,:])
            H = self.sCost*self.dX*self.dt*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
            exitGain.addTerms(H,self.mu[i])
            curval = curval + np.sum(H*self.mu_[i+1,:])

       
        obj = runGain+entryGain+exitGain
        
        self.model.setObjective(obj,GRB.MAXIMIZE)
        self.model.update()
        #print(obj)
        self.model.optimize()
        if self.model.SolCount ==0:
            print('no solution')
       #print('obj=')
       #print(self.model.objVal)
        sol_m = [[self.m[j][i].X for i in range(self.NX)] for j in range(self.Nt-1)]
       # print(sol_m[0])
        sol_mhat = [[self.mhat[j][i].X for i in range(self.NX)] for j in range(self.Nt-1)]
        sol_mu = [[self.mu[j][i].X for i in range(self.NX)] for j in range(self.Nt-1)]
        sol_muhat = [[self.muhat[j][i].X for i in range(self.NX)] for j in range(self.Nt-1)]


        ob_func = obj.getValue()- curval
        return ob_func, curval, np.array(sol_m),np.array(sol_mhat),np.array(sol_mu),np.array(sol_muhat)

    def update(self,weight,m,mhat,mu,muhat):
        # density update with given weight
        self.m_[1:,:] = (1.-weight)*self.m_[1:,:]+weight*m
        self.mhat_[1:,:] = (1.-weight)*self.mhat_[1:,:]+weight*mhat
        self.mu_[1:,:] = (1.-weight)*self.mu_[1:,:]+weight*mu
        self.muhat_[1:,:] = (1.-weight)*self.muhat_[1:,:]+weight*muhat

    def capacity(self):
        return np.sum(self.m_,axis=1)*self.dX
    def pot_capacity(self):
        return np.sum(self.mhat_,axis=1)*self.dX
    def exit_measure(self):
        return np.sum(self.mu_,axis=1)*self.dX
    def entry_measure(self):
        return np.sum(self.muhat_,axis=1)*self.dX
class Conventional_3d(Agent):
    epsilon = 0.5 
    def __init__(self,name,cp,ap):
        Agent.__init__(self,name,cp,ap)
        self.Na=11
        self.Abar=25
        self.da = 1.*(self.Abar)/(self.Na-1)
        self.Amint=5
        self.Amaxt=25
        
        
        self.A = np.linspace(0,self.Abar,self.Na)
        
        self.Amin=math.ceil(self.Amint/self.da)
        self.Amax=math.floor(self.Amaxt/self.da)
        self.cTax = ap['emissions']
        self.fuel = ap['fuel']
        self.cFuel = ap['cFuel']
        kappa = ap['mean reversion']
        theta = ap['long term mean']
        stdIn = ap['standard deviation']
        delta = stdIn*np.sqrt(2.*kappa/theta)
        
        self.m_ = np.zeros((self.Nt,self.Na,self.NX))
        self.mhat_ = np.zeros((self.Nt,self.NX))
        self.mu_ = np.zeros((self.Nt,self.Na,self.NX))
        self.muhat_ = np.zeros((self.Nt,self.NX))
        self.mtau_ = np.zeros((self.Nt,self.NX))
        self.mutau_ = np.zeros((self.Nt,self.NX))
        
        
        V=1.+delta*delta*self.X*self.dt/(self.dX*self.dX)+self.dt/self.da
        V0=1.+delta*delta*self.X*self.dt/(self.dX*self.dX)
        V1 = -delta*delta*self.X*self.dt/(2*self.dX*self.dX)+kappa*(theta-self.X)*self.dt/(2*self.dX)
        V2 = -delta*delta*self.X*self.dt/(2*self.dX*self.dX)-kappa*(theta-self.X)*self.dt/(2*self.dX)
        alpha = (theta/stdIn)*(theta/stdIn)
        bet = theta/stdIn/stdIn
        #indens = ap['initial capacity']*bet*gamma.pdf(bet*self.X,alpha)
        indenshat = ap['potential capacity']*bet*gamma.pdf(bet*self.X,alpha)
        indens =np.zeros((self.Na,self.NX))
        for i in range(1,self.Na):
            indens[i] = ap['initial capacity']*bet*gamma.pdf(bet*self.X,alpha)/self.da/(self.Na-1)
        #indens[1] = ap['initial capacity']*beta.pdf(self.X,alpha,bet)/self.da
        self.preCalc(indens,indenshat,V,V0,V1,V2)
   
    def G(self,x):
        # Gain function
        return (self.epsilon/2+(x-self.epsilon))*(x>self.epsilon)+x*x/2/self.epsilon*(x>0)*(x<=self.epsilon)
    def F(self,x):
        # Supply function
        return (x-self.epsilon>0)+x/self.epsilon*(x>0)*(x<=self.epsilon)
    def mbar(self,t):
        return np.sum(self.m_[t,1:,:],axis=0)*self.da+self.mtau_[t,:]
    def gain(self,p, cp, fp):
        return (convcoef*self.G(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp) - self.rCost)
    def offer(self,p,cp, fp, t):
       # return sum(self.F(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp)*self.mbar(t))*self.dX
        return sum(self.F(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp)*(np.sum(self.m_[t,np.max([1,self.Amin]):self.Amax+1,:],axis=0)*self.dX*self.da+self.mtau_[t,:]*self.dX))
    def ioffer(self,p,cp,fp,t):
        #return sum(self.G(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp)*self.mbar(t))*self.dX
        return sum(self.G(p-self.cFuel*fp[self.fuel]-self.X-self.cTax*cp)*(np.sum(self.m_[t,np.max([1,self.Amin]):self.Amax+1,:],axis=0)*self.dX*self.da+self.mtau_[t,:]*self.dX))

    def full_offer(self,price, cPrice, fPrice):
        # agent supply for given price level
        res = np.zeros(self.Nt)
        for i in range(self.Nt):
            res[i] = self.offer(price[i], cPrice[i], fPrice[:,i],i)
        return res


    def preCalc(self,indens,indenshat,V,V0,V1,V2):
        # Some technical preliminary computations
        self.m_[0,:,:] = indens[:,:]
        self.mhat_[0,:] = indenshat[:]
        with gp.Env(empty=True) as env:
            env.setParam('OutputFlag', 0)
            env.start()
            self.model = gp.Model(env=env)
        self.mhat= [[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.m = [[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Na)] for _ in range(self.Nt-1)]
        self.muhat = [[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.mu = [[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Na)] for _ in range(self.Nt-1)]
        self.mtau=[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.mutau=[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        
        #z=0
        for i in range(0,self.Nt-1):
            for j in range(0,self.NX):
                expr= gp.LinExpr([self.dt,-self.dt],[self.m[i][0][j],self.muhat[i][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
        
        #z!=0
        #case i!=0
        for i in range(1,self.Nt-1):
            #z!=0, j!=Nx-1, j!=0
            for j in range(1,self.NX-1):
                for z in range(1,self.Na):
                    expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],-self.dt/self.da, self.dt,-1.],[self.m[i][z][j],self.m[i][z][j+1],self.m[i][z][j-1],self.m[i][z-1][j],self.mu[i][z][j],self.m[i-1][z][j]])
                    self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                    #print(expr)
                expr = gp.LinExpr([V0[j],V1[j+1],V2[j-1], self.dt,-1.],[self.mhat[i][j],self.mhat[i][j+1],self.mhat[i][j-1],self.muhat[i][j],self.mhat[i-1][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)

                expr=gp.LinExpr([V0[j],V1[j+1],V2[j-1], self.dt,-self.dt,-1.],[self.mtau[i][j],self.mtau[i][j+1],self.mtau[i][j-1],self.mutau[i][j],self.m[i][self.Na-1][j],self.mtau[i-1][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                    
                    
            #z!=0, j=0 or j=NX-1
            for z in range(1,self.Na):
                expr = gp.LinExpr([V[0],V1[1],-self.dt/self.da,self.dt,-1.],[self.m[i][z][0],self.m[i][z][1],self.m[i][z-1][0],self.mu[i][z][0],self.m[i-1][z][0]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],-self.dt/self.da,self.dt,-1.],[self.m[i][z][self.NX-1],self.m[i][z][self.NX-2],self.m[i][z-1][self.NX-1],self.mu[i][z][self.NX-1],self.m[i-1][z][self.NX-1]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            expr = gp.LinExpr([V0[0],V1[1],self.dt,-1.],[self.mhat[i][0],self.mhat[i][1],self.muhat[i][0],self.mhat[i-1][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            
            expr = gp.LinExpr([V0[self.NX-1],V2[self.NX-2],self.dt,-1.],[self.mhat[i][self.NX-1],self.mhat[i][self.NX-2],self.muhat[i][self.NX-1],self.mhat[i-1][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)


            expr=gp.LinExpr([V0[0],V1[1],self.dt,-self.dt,-1.],[self.mtau[i][0],self.mtau[i][1],self.mutau[i][0],self.m[i][self.Na-1][0],self.mtau[i-1][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)


            expr=gp.LinExpr([V0[self.NX-1],V2[self.NX-2], self.dt,-self.dt,-1.],[self.mtau[i][self.NX-1],self.mtau[i][self.NX-2],self.mutau[i][self.NX-1],self.m[i][self.Na-1][self.NX-1],self.mtau[i-1][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                
        #case i=0
        #z!=0, j!=0, j!=NX-1
        for j in range(1,self.NX-1):
            for z in range(1,self.Na):
                expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],-self.dt/self.da,self.dt],[self.m[0][z][j],self.m[0][z][j+1],self.m[0][z][j-1],self.m[0][z-1][j],self.mu[0][z][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[z,j])

            expr = gp.LinExpr([V0[j],V1[j+1],V2[j-1],self.dt],[self.mhat[0][j],self.mhat[0][j+1],self.mhat[0][j-1],self.muhat[0][j]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[j])

            expr=gp.LinExpr([V0[j],V1[j+1],V2[j-1], self.dt,-self.dt],[self.mtau[0][j],self.mtau[0][j+1],self.mtau[0][j-1],self.mutau[0][j],self.m[0][self.Na-1][j]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                
            # i=0,z!=0 j=0 or j=NX-1
        for z in range(1,self.Na):
            expr = gp.LinExpr([V[0],V1[1],-self.dt/self.da,self.dt],[self.m[0][z][0],self.m[0][z][1],self.m[0][z-1][0],self.mu[0][z][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[z,0])

            expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],-self.dt/self.da,self.dt],[self.m[0][z][self.NX-1],self.m[0][z][self.NX-2],self.m[0][z-1][self.NX-1],self.mu[0][z][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[z,self.NX-1])

        expr = gp.LinExpr([V0[0],V1[1],self.dt],[self.mhat[0][0],self.mhat[0][1],self.muhat[0][0]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[0])

        expr = gp.LinExpr([V0[self.NX-1],V2[self.NX-2],self.dt],[self.mhat[0][self.NX-1],self.mhat[0][self.NX-2],self.muhat[0][self.NX-1]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[self.NX-1])

        expr=gp.LinExpr([V0[0],V1[1],self.dt,-self.dt],[self.mtau[0][0],self.mtau[0][1],self.mutau[0][0],self.m[0][self.Na-1][0]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)


        expr=gp.LinExpr([V0[self.NX-1],V2[self.NX-2], self.dt,-self.dt],[self.mtau[0][self.NX-1],self.mtau[0][self.NX-2],self.mutau[0][self.NX-1],self.m[0][self.Na-1][self.NX-1]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)

        

    def bestResponse(self, peakPr, offpeakPr, cPrice, fPrice):
        # best response function
        # peakPr : peak price vector
        # offpeakPr : offpeak price vector
        # fPr : vector of fuel prices
        runGain = gp.LinExpr()
        entryGain = gp.LinExpr()
        exitGain = gp.LinExpr()
        curval = 0
        for i in range(self.Nt-1):
            for j in range(1,self.Na):
                H = self.dX*self.dt*self.da*np.exp(-self.rho*(self.T[i+1]))*(pcoef*self.gain(peakPr[i+1],cPrice[i+1],fPrice[:,i+1])+opcoef*self.gain(offpeakPr[i+1],cPrice[i+1], fPrice[:,i+1]))
                runGain.addTerms(H,self.m[i][j])
                curval = curval + np.sum(H*self.m_[i+1][j])
                
                H = self.sCost*self.dX*self.dt*self.da*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
                exitGain.addTerms(H,self.mu[i][j])
                curval = curval + np.sum(H*self.mu_[i+1][j])
            
            H = self.dX*self.dt*np.exp(-self.rho*(self.T[i+1]))*(pcoef*self.gain(peakPr[i+1],cPrice[i+1],fPrice[:,i+1])+opcoef*self.gain(offpeakPr[i+1],cPrice[i+1], fPrice[:,i+1]))
            runGain.addTerms(H,self.mtau[i])
            curval = curval + np.sum(H*self.mtau_[i+1])

            H = self.sCost*self.dX*self.dt*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
            exitGain.addTerms(H,self.mutau[i])
            curval = curval + np.sum(H*self.mutau_[i+1])
            
            
            
            H = -self.fCost*self.dX*self.dt*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
            entryGain.addTerms(H,self.muhat[i])
            curval = curval + np.sum(H*self.muhat_[i+1])
            
            
       
        obj = runGain+entryGain+exitGain
        
        
        self.model.setObjective(obj,GRB.MAXIMIZE)
        self.model.update()
        
        self.model.optimize()
        
        #print(self.model.objVal)
        
        if self.model.SolCount ==0:
            print('no solution')
        sol_m = [[[self.m[j][z][i].X for i in range(self.NX)] for z in range(self.Na)] for j in range(self.Nt-1)]
        sol_mhat = [[self.mhat[j][i].X for i in range(self.NX)]  for j in range(self.Nt-1)]
        sol_mu = [[[self.mu[j][z][i].X for i in range(self.NX)]for z in range(self.Na)] for j in range(self.Nt-1)]
        sol_muhat = [[self.muhat[j][i].X for i in range(self.NX)]  for j in range(self.Nt-1)]
        sol_mtau = [[self.mtau[j][i].X for i in range(self.NX)]for j in range(self.Nt-1)]
        sol_mutau = [[self.mutau[j][i].X for i in range(self.NX)]  for j in range(self.Nt-1)]

        ob_func = obj.getValue()- curval
        return ob_func, curval, np.array(sol_m),np.array(sol_mhat),np.array(sol_mu),np.array(sol_muhat),np.array(sol_mtau),np.array(sol_mutau)

    def update(self,weight,m,mhat,mu,muhat,mtau,mutau):
        # density update with given weight
        self.m_[1:,:,:] = (1.-weight)*self.m_[1:,:,:]+weight*m
        self.mhat_[1:,:] = (1.-weight)*self.mhat_[1:,:]+weight*mhat
        self.mu_[1:,:,:] = (1.-weight)*self.mu_[1:,:,:]+weight*mu
        self.muhat_[1:,:] = (1.-weight)*self.muhat_[1:,:]+weight*muhat
        self.mtau_[1:,:] = (1.-weight)*self.mtau_[1:,:]+weight*mtau
        self.mutau_[1:,:] = (1.-weight)*self.mutau_[1:,:]+weight*mutau
    def capacity(self):
        return np.sum(np.sum(self.m_[:,1:,:],axis=1),axis=1)*self.da*self.dX+np.sum(self.mtau_,axis=1)*self.dX
    def pot_capacity(self):
        return np.sum(self.mhat_,axis=1)*self.dX
    def exit_measure(self):
        return np.sum(np.sum(self.mu_[:,1:,:],axis=1),axis=1)*self.da*self.dX+np.sum(self.mutau_,axis=1)*self.dX
    def entry_measure(self):
        return np.sum(self.muhat_,axis=1)*self.dX



class Renewable(Agent):
    def __init__(self,name,cp,ap):
        Agent.__init__(self,name,cp,ap)
        self.Na=11
        self.Abar=25
        self.da = 1.*(self.Abar)/(self.Na-1)
        self.Amint=10
        self.Amaxt=25     
        self.A = np.linspace(0,self.Abar,self.Na)
        self.Amin=math.ceil(self.Amint/self.da)
        self.Amax=math.floor(self.Amaxt/self.da)
        kappa = ap['mean reversion']
        theta = ap['long term mean']
        stdIn = ap['standard deviation']
        delta = stdIn*np.sqrt(2.*kappa/(theta*(1-theta)-stdIn*stdIn))
        self.m_ = np.zeros((self.Nt,self.Na,self.NX))
        self.mhat_ = np.zeros((self.Nt,self.NX))
        self.mu_ = np.zeros((self.Nt,self.Na,self.NX))
        self.muhat_ = np.zeros((self.Nt,self.NX))
        self.mtau_ = np.zeros((self.Nt,self.NX))
        self.mutau_ = np.zeros((self.Nt,self.NX))
        V=1.+delta*delta*self.X*(1-self.X)*self.dt/(self.dX*self.dX)+self.dt/self.da
        V0=1.+delta*delta*self.X*(1-self.X)*self.dt/(self.dX*self.dX)
        V1 = -delta*delta*self.X*(1.-self.X)*self.dt/(2*self.dX*self.dX)+kappa*(theta-self.X)*self.dt/(2*self.dX)
        V2 = -delta*delta*self.X*(1.-self.X)*self.dt/(2*self.dX*self.dX)-kappa*(theta-self.X)*self.dt/(2*self.dX)
        alpha = theta*(theta*(1.-theta)/stdIn/stdIn-1.)
        bet = (1.-theta)*(theta*(1.-theta)/stdIn/stdIn-1.)
        #indens = ap['initial capacity']*beta.pdf(self.X,alpha,bet)
        indenshat=ap['potential capacity']*beta.pdf(self.X,alpha,bet)
        indens =np.zeros((self.Na,self.NX))
        for i in range(1,self.Na):
            indens[i] = ap['initial capacity']*beta.pdf(self.X,alpha,bet)/(self.Na-1)/self.da
        #indens[1] = ap['initial capacity']*beta.pdf(self.X,alpha,bet)/self.da
        self.preCalc(indens,indenshat,V,V0,V1,V2)
    def mbar(self,t):
        return np.sum(self.m_[t,1:,:],axis=0)*self.da+self.mtau_[t,:]
    def gain(self,p,cp,fp):
        return convcoef*p*self.X - self.rCost
    def offer(self,t):
       # return sum(self.X*self.mbar(t))*self.dX
        return sum(self.X*(np.sum(self.m_[t,np.max([1,self.Amin]):self.Amax+1,:],axis=0)*self.dX*self.da+self.mtau_[t,:]*self.dX))
    def full_offer(self):
        # agent supply for given price level
        res = np.zeros(self.Nt)
        for i in range(self.Nt):
            res[i] = self.offer(i)
        return res

    def preCalc(self,indens,indenshat,V,V0,V1,V2):
        # Some technical preliminary computations
        self.m_[0,:,:] = indens[:,:]
        self.mhat_[0,:] = indenshat[:]
        with gp.Env(empty=True) as env:
            env.setParam('OutputFlag', 0)
            env.start()
            self.model = gp.Model(env=env)
        self.mhat= [[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.m = [[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Na)] for _ in range(self.Nt-1)]
        self.muhat = [[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.mu = [[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Na)] for _ in range(self.Nt-1)]
        self.mtau=[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        self.mutau=[[self.model.addVar() for _ in range(self.NX)] for _ in range(self.Nt-1)]
        
        #z=0
        for i in range(0,self.Nt-1):
            for j in range(0,self.NX):
                expr= gp.LinExpr([self.dt,-self.dt],[self.m[i][0][j],self.muhat[i][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
        
        #z!=0
        #case i!=0
        for i in range(1,self.Nt-1):
            #z!=0, j!=Nx-1, j!=0
            for j in range(1,self.NX-1):
                for z in range(1,self.Na):
                    expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],-self.dt/self.da, self.dt,-1.],[self.m[i][z][j],self.m[i][z][j+1],self.m[i][z][j-1],self.m[i][z-1][j],self.mu[i][z][j],self.m[i-1][z][j]])
                    self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                    #print(expr)
                expr = gp.LinExpr([V0[j],V1[j+1],V2[j-1], self.dt,-1.],[self.mhat[i][j],self.mhat[i][j+1],self.mhat[i][j-1],self.muhat[i][j],self.mhat[i-1][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)

                expr=gp.LinExpr([V0[j],V1[j+1],V2[j-1], self.dt,-self.dt,-1.],[self.mtau[i][j],self.mtau[i][j+1],self.mtau[i][j-1],self.mutau[i][j],self.m[i][self.Na-1][j],self.mtau[i-1][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                    
                    
            #z!=0, j=0 or j=NX-1
            for z in range(1,self.Na):
                expr = gp.LinExpr([V[0],V1[1],-self.dt/self.da,self.dt,-1.],[self.m[i][z][0],self.m[i][z][1],self.m[i][z-1][0],self.mu[i][z][0],self.m[i-1][z][0]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],-self.dt/self.da,self.dt,-1.],[self.m[i][z][self.NX-1],self.m[i][z][self.NX-2],self.m[i][z-1][self.NX-1],self.mu[i][z][self.NX-1],self.m[i-1][z][self.NX-1]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            expr = gp.LinExpr([V0[0],V1[1],self.dt,-1.],[self.mhat[i][0],self.mhat[i][1],self.muhat[i][0],self.mhat[i-1][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
            
            expr = gp.LinExpr([V0[self.NX-1],V2[self.NX-2],self.dt,-1.],[self.mhat[i][self.NX-1],self.mhat[i][self.NX-2],self.muhat[i][self.NX-1],self.mhat[i-1][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)


            expr=gp.LinExpr([V0[0],V1[1],self.dt,-self.dt,-1.],[self.mtau[i][0],self.mtau[i][1],self.mutau[i][0],self.m[i][self.Na-1][0],self.mtau[i-1][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)


            expr=gp.LinExpr([V0[self.NX-1],V2[self.NX-2], self.dt,-self.dt,-1.],[self.mtau[i][self.NX-1],self.mtau[i][self.NX-2],self.mutau[i][self.NX-1],self.m[i][self.Na-1][self.NX-1],self.mtau[i-1][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                
        #case i=0
        #z!=0, j!=0, j!=NX-1
        for j in range(1,self.NX-1):
            for z in range(1,self.Na):
                expr = gp.LinExpr([V[j],V1[j+1],V2[j-1],-self.dt/self.da,self.dt],[self.m[0][z][j],self.m[0][z][j+1],self.m[0][z][j-1],self.m[0][z-1][j],self.mu[0][z][j]])
                self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[z,j])

            expr = gp.LinExpr([V0[j],V1[j+1],V2[j-1],self.dt],[self.mhat[0][j],self.mhat[0][j+1],self.mhat[0][j-1],self.muhat[0][j]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[j])

            expr=gp.LinExpr([V0[j],V1[j+1],V2[j-1], self.dt,-self.dt],[self.mtau[0][j],self.mtau[0][j+1],self.mtau[0][j-1],self.mutau[0][j],self.m[0][self.Na-1][j]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)
                
            # i=0,z!=0 j=0 or j=NX-1
        for z in range(1,self.Na):
            expr = gp.LinExpr([V[0],V1[1],-self.dt/self.da,self.dt],[self.m[0][z][0],self.m[0][z][1],self.m[0][z-1][0],self.mu[0][z][0]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[z,0])

            expr = gp.LinExpr([V[self.NX-1],V2[self.NX-2],-self.dt/self.da,self.dt],[self.m[0][z][self.NX-1],self.m[0][z][self.NX-2],self.m[0][z-1][self.NX-1],self.mu[0][z][self.NX-1]])
            self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indens[z,self.NX-1])

        expr = gp.LinExpr([V0[0],V1[1],self.dt],[self.mhat[0][0],self.mhat[0][1],self.muhat[0][0]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[0])

        expr = gp.LinExpr([V0[self.NX-1],V2[self.NX-2],self.dt],[self.mhat[0][self.NX-1],self.mhat[0][self.NX-2],self.muhat[0][self.NX-1]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=indenshat[self.NX-1])

        expr=gp.LinExpr([V0[0],V1[1],self.dt,-self.dt],[self.mtau[0][0],self.mtau[0][1],self.mutau[0][0],self.m[0][self.Na-1][0]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)


        expr=gp.LinExpr([V0[self.NX-1],V2[self.NX-2], self.dt,-self.dt],[self.mtau[0][self.NX-1],self.mtau[0][self.NX-2],self.mutau[0][self.NX-1],self.m[0][self.Na-1][self.NX-1]])
        self.model.addLConstr(lhs=expr, sense=GRB.EQUAL, rhs=0.)

        

    def bestResponse(self, peakPr, offpeakPr, cPrice, fPrice):
        # best response function
        # peakPr : peak price vector
        # offpeakPr : offpeak price vector
        # fPr : vector of fuel prices
        runGain = gp.LinExpr()
        entryGain = gp.LinExpr()
        exitGain = gp.LinExpr()
        curval = 0
        for i in range(self.Nt-1):
            for j in range(1,self.Na):
                H = self.dX*self.dt*self.da*np.exp(-self.rho*(self.T[i+1]))*(pcoef*self.gain(peakPr[i+1],cPrice[i+1],fPrice[:,i+1])+opcoef*self.gain(offpeakPr[i+1],cPrice[i+1], fPrice[:,i+1]))
                runGain.addTerms(H,self.m[i][j])
                curval = curval + np.sum(H*self.m_[i+1][j])
                
                H = self.sCost*self.dX*self.dt*self.da*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
                exitGain.addTerms(H,self.mu[i][j])
                curval = curval + np.sum(H*self.mu_[i+1][j])
            
            H = self.dX*self.dt*np.exp(-self.rho*(self.T[i+1]))*(pcoef*self.gain(peakPr[i+1],cPrice[i+1],fPrice[:,i+1])+opcoef*self.gain(offpeakPr[i+1],cPrice[i+1], fPrice[:,i+1]))
            runGain.addTerms(H,self.mtau[i])
            curval = curval + np.sum(H*self.mtau_[i+1])

            H = self.sCost*self.dX*self.dt*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
            exitGain.addTerms(H,self.mutau[i])
            curval = curval + np.sum(H*self.mutau_[i+1])
            
            
            
            H = -self.fCost*self.dX*self.dt*np.exp(-(self.rho+self.gamma0)*(self.T[i+1]))*np.ones(self.NX)
            entryGain.addTerms(H,self.muhat[i])
            curval = curval + np.sum(H*self.muhat_[i+1])
            
            
       
        obj = runGain+entryGain+exitGain
        
        
        self.model.setObjective(obj,GRB.MAXIMIZE)
        self.model.update()
        
        self.model.optimize()
        
        #print(self.model.objVal)
        
        if self.model.SolCount ==0:
            print('no solution')
        sol_m = [[[self.m[j][z][i].X for i in range(self.NX)] for z in range(self.Na)] for j in range(self.Nt-1)]
        sol_mhat = [[self.mhat[j][i].X for i in range(self.NX)]  for j in range(self.Nt-1)]
        sol_mu = [[[self.mu[j][z][i].X for i in range(self.NX)]for z in range(self.Na)] for j in range(self.Nt-1)]
        sol_muhat = [[self.muhat[j][i].X for i in range(self.NX)]  for j in range(self.Nt-1)]
        sol_mtau = [[self.mtau[j][i].X for i in range(self.NX)]for j in range(self.Nt-1)]
        sol_mutau = [[self.mutau[j][i].X for i in range(self.NX)]  for j in range(self.Nt-1)]

        ob_func = obj.getValue()- curval
        return ob_func, curval, np.array(sol_m),np.array(sol_mhat),np.array(sol_mu),np.array(sol_muhat),np.array(sol_mtau),np.array(sol_mutau)

    def update(self,weight,m,mhat,mu,muhat,mtau,mutau):
        # density update with given weight
        self.m_[1:,:,:] = (1.-weight)*self.m_[1:,:,:]+weight*m
        self.mhat_[1:,:] = (1.-weight)*self.mhat_[1:,:]+weight*mhat
        self.mu_[1:,:,:] = (1.-weight)*self.mu_[1:,:,:]+weight*mu
        self.muhat_[1:,:] = (1.-weight)*self.muhat_[1:,:]+weight*muhat
        self.mtau_[1:,:] = (1.-weight)*self.mtau_[1:,:]+weight*mtau
        self.mutau_[1:,:] = (1.-weight)*self.mutau_[1:,:]+weight*mutau
    def capacity(self):
        return np.sum(np.sum(self.m_[:,1:,:],axis=1),axis=1)*self.da*self.dX+np.sum(self.mtau_,axis=1)*self.dX
    def pot_capacity(self):
        return np.sum(self.mhat_,axis=1)*self.dX
    def exit_measure(self):
        return np.sum(np.sum(self.mu_[:,1:,:],axis=1),axis=1)*self.da*self.dX+np.sum(self.mutau_,axis=1)*self.dX
    def entry_measure(self):
        return np.sum(self.muhat_,axis=1)*self.dX

class Simulation:
    # main class for performing the simulation
    def __init__(self, cagents_2d,cagents_3d,ragents, cp):
        # agents: list of agent class instances
        # cp : common parameters
        self.cagents_2d = cagents_2d# conventional
        self.cagents_3d = cagents_3d# conventional
        self.cagents=np.concatenate([self.cagents_2d,self.cagents_3d])
        self.ragents = ragents# renewable
        self.Nt = cp['Nt']
        #self.Nt=5
        self.T = np.linspace(cp['tmin'],cp['tmax'],self.Nt)
        self.pdemand = np.array(cp["demand"])*cp["demand ratio"]/(pcoef*cp["demand ratio"]+opcoef)
        self.opdemand = np.array(cp["demand"])/(pcoef*cp["demand ratio"]+opcoef)
        self.Prp = np.zeros(self.Nt)
        self.Prop = np.zeros(self.Nt)
        self.Nfuels = cp['Nfuels']
        self.fTax = np.interp(self.T,cp['carbon tax'][0],cp['carbon tax'][1])
        self.acoef = np.array(cp['Fsupply'][0])
        self.bcoef = np.array(cp['Fsupply'][1])
        self.fPrice = np.zeros((self.Nfuels,self.Nt))

    def psibar(self,x):
        return np.sum(self.bcoef*(x-self.acoef)**2/2.)

    def calcPrice(self):
        # compute price for given demand profile
        def opfunc(x,t):
            # x = [pp,pop,p1...pK]
            rdem = reduce(lambda a,b:a+b.offer(t),self.ragents,0)
            res = self.psibar(x[2:])
            for ag in self.cagents:
                res = res + pcoef*ag.ioffer(x[0],self.fTax[t],x[2:],t) + opcoef*ag.ioffer(x[1],self.fTax[t],x[2:],t)
            return res+pcoef*x[0]*(rdem-self.pdemand[t])+opcoef*x[1]*(rdem-self.opdemand[t])+pcoef*G0(x[0])+opcoef*G0(x[1])

        for j in range(self.Nt):
            x0 = np.zeros(self.Nfuels+2)
            x0[0] = self.Prp[j]
            x0[1] = self.Prop[j]
            x0[2:] = self.fPrice[:,j]
            bds = [(0,Pmax),(0,Pmax)]+[(0,None)]*self.Nfuels
            opres = minimize(lambda x:opfunc(x,j),x0,bounds=bds)
            
            self.Prp[j]=opres.x[0]
            self.Prop[j] = opres.x[1]
            self.fPrice[:,j] = opres.x[2:]
            #print(opres.x)
            #print(opfunc(opres.x,j))
    def run(self,Niter,tol,power=1., shift=1):
        # run the simulation with maximum Niter iterations
        # the program will stop when the total increase of objective function is less than tol
        # power and shift are coefficients in the weight update formula
        conv = np.zeros(Niter)
        start = time.time()
        for i in range(Niter):
        #for i in range(1):
            self.calcPrice()
            #print(self.Prop)
            weight = np.power(1./(i+shift),power)
            print("Iteration",i)
            message = "Weight: {:.4f}".format(weight)
            obtot = 0
            for a in self.ragents:
                ob, val, m,mhat,mu,muhat,mtau,mutau = a.bestResponse(self.Prp,self.Prop,self.fTax,self.fPrice)
                a.update(weight,m,mhat,mu,muhat,mtau,mutau)
                message = message+"; "+a.name+": {:.2f}".format(ob)
                obtot = obtot+ob
            for a in self.cagents_2d:
                ob, val, m,mhat,mu,muhat = a.bestResponse(self.Prp,self.Prop,self.fTax,self.fPrice)
                a.update(weight,m,mhat,mu,muhat)
                message = message+"; "+a.name+": {:.2f}".format(ob)
                obtot = obtot+ob
            for a in self.cagents_3d:
                ob, val, m,mhat,mu,muhat,mtau,mutau = a.bestResponse(self.Prp,self.Prop,self.fTax,self.fPrice)
                a.update(weight,m,mhat,mu,muhat,mtau,mutau)
                message = message+"; "+a.name+": {:.2f}".format(ob)
                obtot = obtot+ob
            message = message + "; Total: {:.2f}".format(obtot)
            conv[i] = obtot
            print(message)
            if(obtot<tol):
                Niter = i
                break
        self.calcPrice()
        end = time.time()
        return conv, end-start, Niter

    def write(self, scenario_name):
        # write simulation output into a file scenario_name
        output = {"time": self.cagents[0].T, "peak price":self.Prp,"offpeak price":self.Prop,
                  "peak demand":self.pdemand, "offpeak demand":self.opdemand}
        

        
        for a in self.cagents:
            output[a.name+" capacity"] = a.capacity()
            output[a.name+" potential capacity"] = a.pot_capacity()
            output[a.name+" exit measure"] = a.exit_measure()
            output[a.name+" entry measure"] = a.entry_measure()
            output[a.name+" peak supply"] = a.full_offer(self.Prp,self.fTax, self.fPrice)
            output[a.name+" offpeak supply"] = a.full_offer(self.Prop,self.fTax,self.fPrice)
        for a in self.ragents:
            output[a.name+" capacity"] = a.capacity()
            output[a.name+" potential capacity"] = a.pot_capacity()
            output[a.name+" exit measure"] = a.exit_measure()
            output[a.name+" entry measure"] = a.entry_measure()
            output[a.name+" peak supply"] = a.full_offer()
            output[a.name+" offpeak supply"] = a.full_offer()
        for i in range(self.Nfuels):
            output["Fuel "+str(i)] = self.fPrice[i,:]
        df = pd.DataFrame.from_dict(output)
        df.to_csv(scenario_name+'.csv')
        return output


def getpar(fname):
    # service function: extract parameter dictionary from file
    with open(fname) as f:
        data = f.read()
    return eval(data)

# %%
#from elecmarket import *
import os as os
scenario_name = "test" # this will be the name of the output file & folder

cp = getpar("common_params.py")

# list of conventional agents; modify this to add / remove agent types
cagents_2d = [Conventional_2d('Coal',cp,getpar('coal.py'))]
cagents_3d=[Conventional_3d('Gas',cp,getpar('gas.py'))]
# list of renewable agents; modify this to add / remove agent types
ragents = [Renewable('Renewable',cp,getpar('renewable.py'))]

# %%
Niter = cp['iterations']
tol = cp['tolerance']
sim = Simulation(cagents_2d,cagents_3d,ragents,cp)
conv, elapsed, Nit = sim.run(Niter, tol, cp['power'], cp['offset'])
# Out:
# Iteration 0
# Weight: 0.2759; Renewable: 315992.98; Coal: 379095.35; Gas: 439506.99; Total: 1134595.33
# Iteration 1
# Weight: 0.2385; Renewable: 200056.47; Coal: 213249.78; Gas: 223334.60; Total: 636640.85
# Iteration 2
# Weight: 0.2108; Renewable: 65912.64; Coal: 75424.25; Gas: 65265.80; Total: 206602.68
# Iteration 3
# Weight: 0.1895; Renewable: 33755.77; Coal: 30590.81; Gas: 19924.10; Total: 84270.69
# Iteration 4
# Weight: 0.1724; Renewable: 34366.58; Coal: 15158.23; Gas: 7798.44; Total: 57323.25
# Iteration 5
# Weight: 0.1585; Renewable: 32441.03; Coal: 8964.57; Gas: 3946.00; Total: 45351.60
# Iteration 6
# Weight: 0.1469; Renewable: 29007.01; Coal: 5743.75; Gas: 2933.46; Total: 37684.22
# Iteration 7
# Weight: 0.1370; Renewable: 25671.05; Coal: 4306.92; Gas: 2623.59; Total: 32601.56
# Iteration 8
# Weight: 0.1285; Renewable: 22362.34; Coal: 3164.61; Gas: 2568.23; Total: 28095.18
# Iteration 9
# Weight: 0.1211; Renewable: 19719.14; Coal: 2590.73; Gas: 2309.93; Total: 24619.79
# Iteration 10
# Weight: 0.1146; Renewable: 17265.89; Coal: 2090.53; Gas: 2116.20; Total: 21472.62
# Iteration 11
# Weight: 0.1088; Renewable: 15294.99; Coal: 1799.25; Gas: 1910.42; Total: 19004.66
# Iteration 12
# Weight: 0.1037; Renewable: 13579.65; Coal: 1537.04; Gas: 1733.98; Total: 16850.67
# Iteration 13
# Weight: 0.0990; Renewable: 12144.30; Coal: 1345.11; Gas: 1560.75; Total: 15050.16
# Iteration 14
# Weight: 0.0948; Renewable: 10916.18; Coal: 1187.78; Gas: 1413.79; Total: 13517.75
# Iteration 15
# Weight: 0.0910; Renewable: 9868.15; Coal: 1056.85; Gas: 1288.26; Total: 12213.26
# Iteration 16
# Weight: 0.0875; Renewable: 8953.83; Coal: 956.82; Gas: 1171.80; Total: 11082.45
# Iteration 17
# Weight: 0.0843; Renewable: 8146.83; Coal: 868.76; Gas: 1071.39; Total: 10086.97
# Iteration 18
# Weight: 0.0814; Renewable: 7447.21; Coal: 789.21; Gas: 984.42; Total: 9220.85
# Iteration 19
# Weight: 0.0787; Renewable: 6824.55; Coal: 721.57; Gas: 905.13; Total: 8451.25
# Iteration 20
# Weight: 0.0761; Renewable: 6281.67; Coal: 660.91; Gas: 837.61; Total: 7780.19
# Iteration 21
# Weight: 0.0738; Renewable: 5793.27; Coal: 607.03; Gas: 777.78; Total: 7178.08
# Iteration 22
# Weight: 0.0716; Renewable: 5363.54; Coal: 561.44; Gas: 719.06; Total: 6644.04
# Iteration 23
# Weight: 0.0695; Renewable: 4967.75; Coal: 519.62; Gas: 668.04; Total: 6155.41
# Iteration 24
# Weight: 0.0676; Renewable: 4616.98; Coal: 482.57; Gas: 621.77; Total: 5721.33
# Iteration 25
# Weight: 0.0658; Renewable: 4299.70; Coal: 449.53; Gas: 580.04; Total: 5329.28
# Iteration 26
# Weight: 0.0641; Renewable: 4011.10; Coal: 419.87; Gas: 541.92; Total: 4972.89
# Iteration 27
# Weight: 0.0625; Renewable: 3750.52; Coal: 392.54; Gas: 507.39; Total: 4650.45
# Iteration 28
# Weight: 0.0610; Renewable: 3512.35; Coal: 367.87; Gas: 476.18; Total: 4356.41
# Iteration 29
# Weight: 0.0595; Renewable: 3296.35; Coal: 344.39; Gas: 447.75; Total: 4088.49
# Iteration 30
# Weight: 0.0582; Renewable: 3097.69; Coal: 323.47; Gas: 421.31; Total: 3842.47
# Iteration 31
# Weight: 0.0569; Renewable: 2914.89; Coal: 304.38; Gas: 396.88; Total: 3616.15
# Iteration 32
# Weight: 0.0556; Renewable: 2747.24; Coal: 286.76; Gas: 374.39; Total: 3408.38
# Iteration 33
# Weight: 0.0545; Renewable: 2592.68; Coal: 270.59; Gas: 353.89; Total: 3217.15
# Iteration 34
# Weight: 0.0534; Renewable: 2450.97; Coal: 254.87; Gas: 337.19; Total: 3043.03
# Iteration 35
# Weight: 0.0523; Renewable: 2320.57; Coal: 241.63; Gas: 318.08; Total: 2880.28
# Iteration 36
# Weight: 0.0513; Renewable: 2196.52; Coal: 228.14; Gas: 301.78; Total: 2726.45
# Iteration 37
# Weight: 0.0503; Renewable: 2083.52; Coal: 216.58; Gas: 286.67; Total: 2586.77
# Iteration 38
# Weight: 0.0493; Renewable: 1976.75; Coal: 205.39; Gas: 271.67; Total: 2453.81
# Iteration 39
# Weight: 0.0484; Renewable: 1878.67; Coal: 194.94; Gas: 258.24; Total: 2331.86
# Iteration 40
# Weight: 0.0476; Renewable: 1787.12; Coal: 185.33; Gas: 246.00; Total: 2218.44
# Iteration 41
# Weight: 0.0468; Renewable: 1701.96; Coal: 176.90; Gas: 234.78; Total: 2113.63
# Iteration 42
# Weight: 0.0460; Renewable: 1621.10; Coal: 168.22; Gas: 223.35; Total: 2012.67
# Iteration 43
# Weight: 0.0452; Renewable: 1546.26; Coal: 160.36; Gas: 212.97; Total: 1919.59
# Iteration 44
# Weight: 0.0444; Renewable: 1476.08; Coal: 153.06; Gas: 203.29; Total: 1832.43
# Iteration 45
# Weight: 0.0437; Renewable: 1410.11; Coal: 146.14; Gas: 194.46; Total: 1750.71
# Iteration 46
# Weight: 0.0430; Renewable: 1348.50; Coal: 140.01; Gas: 186.51; Total: 1675.02
# Iteration 47
# Weight: 0.0424; Renewable: 1289.66; Coal: 133.74; Gas: 178.13; Total: 1601.53
# Iteration 48
# Weight: 0.0417; Renewable: 1234.80; Coal: 127.96; Gas: 170.46; Total: 1533.22
# Iteration 49
# Weight: 0.0411; Renewable: 1183.02; Coal: 122.57; Gas: 163.25; Total: 1468.84
# Iteration 50
# Weight: 0.0405; Renewable: 1134.15; Coal: 117.54; Gas: 156.44; Total: 1408.12
# Iteration 51
# Weight: 0.0399; Renewable: 1088.16; Coal: 112.65; Gas: 150.39; Total: 1351.20
# Iteration 52
# Weight: 0.0394; Renewable: 1044.86; Coal: 108.32; Gas: 144.77; Total: 1297.96
# Iteration 53
# Weight: 0.0388; Renewable: 1003.07; Coal: 104.01; Gas: 138.79; Total: 1245.87
# Iteration 54
# Weight: 0.0383; Renewable: 963.95; Coal: 99.89; Gas: 133.26; Total: 1197.10
# Iteration 55
# Weight: 0.0378; Renewable: 926.84; Coal: 95.97; Gas: 128.09; Total: 1150.91
# Iteration 56
# Weight: 0.0373; Renewable: 891.84; Coal: 92.26; Gas: 123.17; Total: 1107.28
# Iteration 57
# Weight: 0.0368; Renewable: 858.39; Coal: 88.88; Gas: 119.19; Total: 1066.47
# Iteration 58
# Weight: 0.0364; Renewable: 826.99; Coal: 85.78; Gas: 114.89; Total: 1027.65
# Iteration 59
# Weight: 0.0359; Renewable: 796.52; Coal: 82.45; Gas: 110.36; Total: 989.32
# Iteration 60
# Weight: 0.0355; Renewable: 767.86; Coal: 79.42; Gas: 106.23; Total: 953.51
# Iteration 61
# Weight: 0.0350; Renewable: 740.59; Coal: 76.55; Gas: 102.75; Total: 919.88
# Iteration 62
# Weight: 0.0346; Renewable: 714.76; Coal: 74.02; Gas: 99.48; Total: 888.26
# Iteration 63
# Weight: 0.0342; Renewable: 689.70; Coal: 71.38; Gas: 95.75; Total: 856.84
# Iteration 64
# Weight: 0.0338; Renewable: 666.07; Coal: 68.87; Gas: 92.32; Total: 827.26
# Iteration 65
# Weight: 0.0334; Renewable: 643.56; Coal: 66.49; Gas: 89.06; Total: 799.12
# Iteration 66
# Weight: 0.0330; Renewable: 622.05; Coal: 64.24; Gas: 86.30; Total: 772.59
# Iteration 67
# Weight: 0.0327; Renewable: 601.51; Coal: 62.19; Gas: 83.88; Total: 747.58
# Iteration 68
# Weight: 0.0323; Renewable: 581.71; Coal: 60.11; Gas: 80.93; Total: 722.76
# Iteration 69
# Weight: 0.0320; Renewable: 562.86; Coal: 58.10; Gas: 78.09; Total: 699.05
# Iteration 70
# Weight: 0.0316; Renewable: 544.79; Coal: 56.32; Gas: 75.49; Total: 676.61
# Iteration 71
# Weight: 0.0313; Renewable: 527.60; Coal: 54.52; Gas: 73.06; Total: 655.18
# Iteration 72
# Weight: 0.0310; Renewable: 511.16; Coal: 52.99; Gas: 71.53; Total: 635.68
# Iteration 73
# Weight: 0.0306; Renewable: 495.14; Coal: 51.30; Gas: 68.97; Total: 615.40
# Iteration 74
# Weight: 0.0303; Renewable: 479.96; Coal: 49.57; Gas: 66.67; Total: 596.21
# Iteration 75
# Weight: 0.0300; Renewable: 465.37; Coal: 48.06; Gas: 64.53; Total: 577.97
# Iteration 76
# Weight: 0.0297; Renewable: 451.42; Coal: 46.66; Gas: 62.55; Total: 560.63
# Iteration 77
# Weight: 0.0294; Renewable: 438.03; Coal: 45.34; Gas: 61.33; Total: 544.71
# Iteration 78
# Weight: 0.0292; Renewable: 425.01; Coal: 44.07; Gas: 59.23; Total: 528.30
# Iteration 79
# Weight: 0.0289; Renewable: 412.62; Coal: 42.66; Gas: 57.35; Total: 512.63
# Iteration 80
# Weight: 0.0286; Renewable: 400.68; Coal: 41.42; Gas: 55.58; Total: 497.68
# Iteration 81
# Weight: 0.0283; Renewable: 389.22; Coal: 40.24; Gas: 53.95; Total: 483.42
# Iteration 82
# Weight: 0.0281; Renewable: 378.15; Coal: 39.15; Gas: 52.62; Total: 469.92
# Iteration 83
# Weight: 0.0278; Renewable: 367.65; Coal: 38.27; Gas: 51.74; Total: 457.66
# Iteration 84
# Weight: 0.0276; Renewable: 357.30; Coal: 37.02; Gas: 49.95; Total: 444.27
# Iteration 85
# Weight: 0.0273; Renewable: 347.44; Coal: 35.91; Gas: 48.34; Total: 431.68
# Iteration 86
# Weight: 0.0271; Renewable: 337.93; Coal: 34.89; Gas: 46.94; Total: 419.76
# Iteration 87
# Weight: 0.0269; Renewable: 328.76; Coal: 34.00; Gas: 45.94; Total: 408.70
# Iteration 88
# Weight: 0.0266; Renewable: 320.01; Coal: 33.37; Gas: 45.09; Total: 398.47
# Iteration 89
# Weight: 0.0264; Renewable: 311.41; Coal: 32.23; Gas: 43.58; Total: 387.22
# Iteration 90
# Weight: 0.0262; Renewable: 303.18; Coal: 31.34; Gas: 42.19; Total: 376.70
# Iteration 91
# Weight: 0.0260; Renewable: 295.22; Coal: 30.49; Gas: 41.01; Total: 366.72
# Iteration 92
# Weight: 0.0257; Renewable: 287.56; Coal: 29.68; Gas: 39.89; Total: 357.13
# Iteration 93
# Weight: 0.0255; Renewable: 280.17; Coal: 28.97; Gas: 39.25; Total: 348.39
# Iteration 94
# Weight: 0.0253; Renewable: 273.10; Coal: 28.55; Gas: 38.53; Total: 340.19
# Iteration 95
# Weight: 0.0251; Renewable: 266.12; Coal: 27.49; Gas: 37.22; Total: 330.82
# Iteration 96
# Weight: 0.0249; Renewable: 259.40; Coal: 26.82; Gas: 36.08; Total: 322.30
# Iteration 97
# Weight: 0.0247; Renewable: 252.92; Coal: 26.12; Gas: 35.13; Total: 314.17
# Iteration 98
# Weight: 0.0245; Renewable: 246.67; Coal: 25.48; Gas: 34.22; Total: 306.36
# Iteration 99
# Weight: 0.0243; Renewable: 240.66; Coal: 25.03; Gas: 33.93; Total: 299.62
# Iteration 100
# Weight: 0.0242; Renewable: 234.75; Coal: 24.32; Gas: 32.82; Total: 291.89
# Iteration 101
# Weight: 0.0240; Renewable: 229.08; Coal: 23.67; Gas: 31.94; Total: 284.69
# Iteration 102
# Weight: 0.0238; Renewable: 223.56; Coal: 23.12; Gas: 31.07; Total: 277.75
# Iteration 103
# Weight: 0.0236; Renewable: 218.26; Coal: 22.59; Gas: 30.28; Total: 271.13
# Iteration 104
# Weight: 0.0234; Renewable: 213.08; Coal: 22.13; Gas: 30.07; Total: 265.29
# Iteration 105
# Weight: 0.0233; Renewable: 208.13; Coal: 21.73; Gas: 29.43; Total: 259.30
# Iteration 106
# Weight: 0.0231; Renewable: 203.25; Coal: 21.08; Gas: 28.49; Total: 252.81
# Iteration 107
# Weight: 0.0229; Renewable: 198.55; Coal: 20.55; Gas: 27.63; Total: 246.72
# Iteration 108
# Weight: 0.0228; Renewable: 193.99; Coal: 20.04; Gas: 26.95; Total: 240.98
# Iteration 109
# Weight: 0.0226; Renewable: 189.57; Coal: 19.59; Gas: 26.39; Total: 235.56
# Iteration 110
# Weight: 0.0225; Renewable: 185.31; Coal: 19.17; Gas: 26.14; Total: 230.63
# Iteration 111
# Weight: 0.0223; Renewable: 181.13; Coal: 18.73; Gas: 25.38; Total: 225.23
# Iteration 112
# Weight: 0.0222; Renewable: 177.08; Coal: 18.30; Gas: 24.70; Total: 220.08
# Iteration 113
# Weight: 0.0220; Renewable: 173.15; Coal: 17.89; Gas: 24.09; Total: 215.13
# Iteration 114
# Weight: 0.0219; Renewable: 169.33; Coal: 17.51; Gas: 23.54; Total: 210.38
# Iteration 115
# Weight: 0.0217; Renewable: 165.64; Coal: 17.20; Gas: 23.53; Total: 206.37
# Iteration 116
# Weight: 0.0216; Renewable: 162.08; Coal: 16.97; Gas: 23.00; Total: 202.05
# Iteration 117
# Weight: 0.0214; Renewable: 158.55; Coal: 16.43; Gas: 22.26; Total: 197.24
# Iteration 118
# Weight: 0.0213; Renewable: 155.15; Coal: 16.04; Gas: 21.69; Total: 192.88
# Iteration 119
# Weight: 0.0211; Renewable: 151.84; Coal: 15.69; Gas: 21.08; Total: 188.61
# Iteration 120
# Weight: 0.0210; Renewable: 148.64; Coal: 15.39; Gas: 20.77; Total: 184.80
# Iteration 121
# Weight: 0.0209; Renewable: 145.53; Coal: 15.21; Gas: 20.61; Total: 181.35
# Iteration 122
# Weight: 0.0207; Renewable: 142.47; Coal: 14.77; Gas: 19.99; Total: 177.22
# Iteration 123
# Weight: 0.0206; Renewable: 139.50; Coal: 14.44; Gas: 19.43; Total: 173.38
# Iteration 124
# Weight: 0.0205; Renewable: 136.63; Coal: 14.13; Gas: 18.99; Total: 169.75
# Iteration 125
# Weight: 0.0204; Renewable: 133.83; Coal: 13.83; Gas: 18.59; Total: 166.25
# Iteration 126
# Weight: 0.0202; Renewable: 131.10; Coal: 13.57; Gas: 18.41; Total: 163.08
# Iteration 127
# Weight: 0.0201; Renewable: 128.48; Coal: 13.45; Gas: 18.21; Total: 160.13
# Iteration 128
# Weight: 0.0200; Renewable: 125.87; Coal: 13.04; Gas: 17.63; Total: 156.54
# Iteration 129
# Weight: 0.0199; Renewable: 123.34; Coal: 12.78; Gas: 17.18; Total: 153.30
# Iteration 130
# Weight: 0.0198; Renewable: 120.89; Coal: 12.50; Gas: 16.80; Total: 150.19
# Iteration 131
# Weight: 0.0196; Renewable: 118.51; Coal: 12.24; Gas: 16.46; Total: 147.21
# Iteration 132
# Weight: 0.0195; Renewable: 116.18; Coal: 12.03; Gas: 16.23; Total: 144.45
# Iteration 133
# Weight: 0.0194; Renewable: 113.93; Coal: 11.88; Gas: 16.16; Total: 141.97
# Iteration 134
# Weight: 0.0193; Renewable: 111.70; Coal: 11.62; Gas: 15.66; Total: 138.98
# Iteration 135
# Weight: 0.0192; Renewable: 109.54; Coal: 11.35; Gas: 15.29; Total: 136.18
# Iteration 136
# Weight: 0.0191; Renewable: 107.44; Coal: 11.11; Gas: 15.01; Total: 133.55
# Iteration 137
# Weight: 0.0190; Renewable: 105.40; Coal: 11.22; Gas: 15.21; Total: 131.84
# Iteration 138
# Weight: 0.0189; Renewable: 103.39; Coal: 10.75; Gas: 14.75; Total: 128.89
# Iteration 139
# Weight: 0.0188; Renewable: 101.43; Coal: 10.63; Gas: 14.24; Total: 126.30
# Iteration 140
# Weight: 0.0187; Renewable: 99.52; Coal: 10.36; Gas: 13.87; Total: 123.74
# Iteration 141
# Weight: 0.0186; Renewable: 97.67; Coal: 10.12; Gas: 13.57; Total: 121.36
# Iteration 142
# Weight: 0.0185; Renewable: 95.86; Coal: 9.91; Gas: 13.43; Total: 119.20
# Iteration 143
# Weight: 0.0184; Renewable: 94.11; Coal: 9.93; Gas: 13.49; Total: 117.53
# Iteration 144
# Weight: 0.0183; Renewable: 92.37; Coal: 9.60; Gas: 13.10; Total: 115.07
# Iteration 145
# Weight: 0.0182; Renewable: 90.67; Coal: 9.39; Gas: 12.72; Total: 112.78
# Iteration 146
# Weight: 0.0181; Renewable: 89.03; Coal: 9.21; Gas: 12.40; Total: 110.64
# Iteration 147
# Weight: 0.0180; Renewable: 87.41; Coal: 9.14; Gas: 12.49; Total: 109.05
# Iteration 148
# Weight: 0.0179; Renewable: 85.86; Coal: 9.04; Gas: 12.33; Total: 107.23
# Iteration 149
# Weight: 0.0178; Renewable: 84.31; Coal: 8.76; Gas: 11.97; Total: 105.05
# Iteration 150
# Weight: 0.0177; Renewable: 82.81; Coal: 8.61; Gas: 11.61; Total: 103.03
# Iteration 151
# Weight: 0.0176; Renewable: 81.34; Coal: 8.45; Gas: 11.34; Total: 101.13
# Iteration 152
# Weight: 0.0175; Renewable: 79.91; Coal: 8.27; Gas: 11.13; Total: 99.31

# %%
print('Elapsed time: ', elapsed)
out = sim.write(scenario_name)
# Out:
# Elapsed time:  507.651762008667

# %%
try:
    os.mkdir(scenario_name)
except FileExistsError:
    print('Directory already exists')
os.system("cp common_params.py "+scenario_name+"/common_params.py")

# parameter files are copied to output directory; change this if you change agent types
os.system("cp coal.py "+scenario_name+"/coal.py")
os.system("cp gas.py "+scenario_name+"/gas.py")
os.system("cp renewable.py "+scenario_name+"/renewable.py")

os.system("cp "+scenario_name+'.csv '+scenario_name+"/"+scenario_name+".csv")


plt.figure(figsize=(14,5))
plt.subplot(121)
plt.plot(2018+out['time'], out['peak price'], label='peak price')
plt.plot(2018+out['time'], out['offpeak price'], label='offpeak price')
plt.legend()
plt.title('Electricity price')
plt.subplot(122)

# Plotting the capacity for each agent type; modify this if you change agent types
plt.plot(2018+out['time'], out['Coal capacity'], label='Coal capacity')
plt.plot(2018+out['time'], out['Gas capacity'],label='Gas capacity')
plt.plot(2018+out['time'], out['Renewable capacity'], label='Renewable capacity')
plt.legend()
plt.title('Installed capacity')
plt.savefig(scenario_name+"/"+'price_capacity.pdf', format='pdf')

plt.figure(figsize=(14, 5))
plt.subplot(121)
plt.plot(2018+out['time'], sim.pdemand, label='peak demand')
plt.plot(2018+out['time'], sim.opdemand, label='offpeak demand')
plt.legend()
plt.title('Electricity demand')
plt.subplot(122)

# Plotting the fuel prices; modify this if you change fuel types
plt.plot(2018+out['time'], out['Fuel 0'], label='Coal price')
plt.plot(2018+out['time'], out['Fuel 1'], label='Gas price')
plt.legend()
plt.title('Fuel price')
#plt.plot(2018+out['time'],np.interp(out['time'],cp["carbon tax"][0],cp["carbon tax"][1]))
plt.savefig(scenario_name+"/"+'demand_fuelprice.pdf',format='pdf')


plt.figure(figsize=(14,5))
plt.subplot(121)

# Plotting the supply for each agent; modify this if you change agent types
plt.bar(2018+out['time'],out['Coal peak supply'],width=0.25,label='Coal supply')
plt.bar(2018+out['time'],out['Gas peak supply'],width=0.25,
        bottom=out['Coal peak supply'],label='Gas supply')
plt.bar(2018+out['time'],out['Renewable peak supply'],width=0.25,
        bottom=out['Gas peak supply']+out['Coal peak supply'],label='Renewable supply')
#plt.ylim([0,80])
plt.title('Conventional/ renewable peak supply, GW')
plt.legend()
plt.subplot(122)
plt.bar(2018+out['time'],out['Coal offpeak supply'],width=0.5,label='Coal supply')
plt.bar(2018+out['time'],out['Gas offpeak supply'],width=0.25,
        bottom=out['Coal offpeak supply'],label='Gas supply')
plt.bar(2018+out['time'],out['Renewable offpeak supply'],width=0.25,
        bottom=out['Gas offpeak supply']+out['Coal offpeak supply'],label='Renewable supply')

plt.title('Conventional/ renewable off-peak supply, GW')

#plt.ylim([0,80])


plt.legend()
plt.savefig(scenario_name+"/"+'supply.pdf',format='pdf')
plt.show()



print('Elapsed time: ', elapsed)
# Out:
# Directory already exists
# Elapsed time:  507.651762008667

# %%
ragents[0].capacity()
# Out:
# array([  4.99990399,   5.07734054,   5.08076172,   5.0831482 ,
#          5.08437651,   5.08539536,   5.08600603,   5.08655743,
#          5.08683245,   5.08697996,   5.08714518,   5.08744905,
#          5.08757459,   5.08759359,   5.08763097,   6.39991276,
#          7.00504687,   7.52850583,   8.62155005,  11.71529902,
#         13.41085248,  14.87670835,  17.63853704,  21.59052185,
#         24.12824409,  26.38313679,  30.46866367,  35.83845833,
#         39.22773884,  42.1839723 ,  44.88778376,  52.80186643,
#         56.70606649,  58.49400353,  62.30475971,  67.32765714,
#         70.47307583,  73.16747562,  75.56206829,  81.71399488,
#         84.51257616,  86.77394088,  88.7040409 ,  93.1659272 ,
#         95.03819408,  96.02042864,  97.51840533,  99.24425327,
#        100.22740499, 100.96285841, 101.57790664, 102.43115388,
#        102.89679606, 103.22904285, 103.50265445, 103.86258626,
#        104.05614193, 104.14573651, 104.24010386, 104.32477644,
#        104.36846348, 104.3966318 , 104.41782772, 104.44291257,
#        104.45734828, 104.46212853, 104.4661625 , 104.47139126,
#        104.47220182, 104.47140771, 104.47018235, 104.46865934,
#        104.46679872, 104.4645151 , 104.4621095 , 104.45963828,
#        104.45716027, 104.45468113, 104.45220212, 104.44972341,
#        104.44724499, 104.44476696, 104.44228935, 104.43981214,
#        104.4373353 , 104.43485883, 104.43238269, 104.42990687,
#        104.42743132, 104.42495605, 104.42248102, 104.42000622,
#        104.41753164, 104.41505725, 104.41258304, 104.410109  ,
#        104.40763512, 104.40516139, 104.4026878 , 104.40021434,
#        104.397741  ])
